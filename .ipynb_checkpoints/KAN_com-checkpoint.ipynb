# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import argparse
import os
import math
import random
import time
from typing import Tuple, List, Optional, Dict

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import datasets, transforms
from torchvision.datasets.folder import default_loader
from torchvision.utils import make_grid, save_image
import matplotlib.pyplot as plt

from skimage.metrics import peak_signal_noise_ratio, structural_similarity
import pandas as pd

FastKANModule = None
_fastkan_import_error = None
try:
    # najczęściej: pip install fast-kan
    from fastkan import FastKAN as FastKANModule
except Exception as e1:
    _fastkan_import_error = e1
    try:
        # alternatywna nazwa paczki
        from fast_kan import FastKAN as FastKANModule
        _fastkan_import_error = None
    except Exception as e2:
        _fastkan_import_error = (e1, e2)

# ====================================================
# Narzędzia
# ====================================================

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)


def count_params(model: nn.Module) -> int:
    return sum(p.numel() for p in model.parameters())


def to_numpy_img(batch_tensor: torch.Tensor) -> np.ndarray:
    x = batch_tensor.detach().cpu().numpy()
    x = np.clip(x, 0.0, 1.0)
    return x[:, 0, :, :]


def psnr_ssim_batch(x: torch.Tensor, y: torch.Tensor) -> Tuple[float, float]:
    x_np = to_numpy_img(x)
    y_np = to_numpy_img(y)
    ps, ss = [], []
    for i in range(x_np.shape[0]):
        ps.append(peak_signal_noise_ratio(x_np[i], y_np[i], data_range=1.0))
        try:
            ss.append(structural_similarity(x_np[i], y_np[i], data_range=1.0, channel_axis=None))
        except TypeError:
            ss.append(structural_similarity(x_np[i], y_np[i], data_range=1.0, multichannel=False))
    return float(np.mean(ps)), float(np.mean(ss))


# ====================================================
# SPLAJNY dla KAN
# ====================================================

def _linear_spline(x, grid, coeff):
    grid_min, grid_max = grid[0], grid[-1]
    G = grid.shape[0]
    t = (x - grid_min) / (grid_max - grid_min) * (G - 1)
    t = torch.clamp(t, 0, G - 1 - 1e-6)
    t_floor = torch.floor(t)
    frac = t - t_floor
    li = t_floor.long().unsqueeze(-1)
    ui = (li + 1).clamp(max=G - 1)
    c0 = torch.gather(coeff, -1, li).squeeze(-1)
    c1 = torch.gather(coeff, -1, ui).squeeze(-1)
    return c0 * (1.0 - frac) + c1 * frac


def _bezier_spline(x, grid, coeff):
    grid_min, grid_max = grid[0], grid[-1]
    t = torch.clamp((x - grid_min) / (grid_max - grid_min), 0.0, 1.0)
    res = coeff
    N = coeff.shape[-1]
    for k in range(1, N):
        res = res[..., :N - k] * (1 - t).unsqueeze(-1) + res[..., 1:N - k + 1] * t.unsqueeze(-1)
    return res[..., 0]


def _catmull_rom_spline(x, grid, coeff):
    grid_min, grid_max = grid[0], grid[-1]
    N = coeff.shape[-1]
    segs = N - 3
    t_norm = torch.clamp((x - grid_min) / (grid_max - grid_min) * segs, 0, segs - 1e-6)
    i = torch.floor(t_norm).to(torch.int64)
    t_loc = (t_norm - i.to(x.dtype))
    idx = torch.stack([i, (i + 1).clamp(max=N - 1), (i + 2).clamp(max=N - 1), (i + 3).clamp(max=N - 1)], dim=-1)
    P = torch.gather(coeff, -1, idx)
    t = t_loc
    t2, t3 = t * t, t * t * t
    return 0.5 * (
        2 * P[..., 1] +
        (-P[..., 0] + P[..., 2]) * t +
        (2 * P[..., 0] - 5 * P[..., 1] + 4 * P[..., 2] - P[..., 3]) * t2 +
        (-P[..., 0] + 3 * P[..., 1] - 3 * P[..., 2] + P[..., 3]) * t3
    )


def _bspline_spline(x, grid, coeff):
    grid_min, grid_max = grid[0], grid[-1]
    N = coeff.shape[-1]
    segs = N - 3
    t_norm = torch.clamp((x - grid_min) / (grid_max - grid_min) * segs, 0, segs - 1e-6)
    i = torch.floor(t_norm).to(torch.int64)
    t_loc = t_norm - i.to(x.dtype)
    idx = torch.stack([i, (i + 1).clamp(max=N - 1), (i + 2).clamp(max=N - 1), (i + 3).clamp(max=N - 1)], dim=-1)
    P = torch.gather(coeff, -1, idx)
    t = t_loc
    t2, t3 = t * t, t * t * t
    B0 = (1 - t) ** 3 / 6.0
    B1 = (3 * t3 - 6 * t2 + 4) / 6.0
    B2 = (-3 * t3 + 3 * t2 + 3 * t + 1) / 6.0
    B3 = t3 / 6.0
    return P[..., 0] * B0 + P[..., 1] * B1 + P[..., 2] * B2 + P[..., 3] * B3


def spline_interpolate(x, grid, coeff, spline_type: str):
    if spline_type == "linear":
        return _linear_spline(x, grid, coeff)
    elif spline_type == "bezier":
        return _bezier_spline(x, grid, coeff)
    elif spline_type == "catmull_rom":
        return _catmull_rom_spline(x, grid, coeff)
    elif spline_type == "bspline":
        return _bspline_spline(x, grid, coeff)
    elif spline_type in ("hermite", "nurbs"):
        return _linear_spline(x, grid, coeff)
    else:
        raise ValueError(f"Unknown spline: {spline_type}")


# ====================================================
# KAN 
# ====================================================

class KANLayer(nn.Module):
    def __init__(self, n_in: int, n_out: int, num_grid: int = 6, grid_min: float = -5.0, grid_max: float = 5.0,
                 spline_type: str = "bspline"):
        super().__init__()
        self.n_in, self.n_out, self.spline_type = n_in, n_out, spline_type
        grid = torch.linspace(grid_min, grid_max, steps=num_grid)
        self.register_buffer("grid", grid)
        self.coeffs = nn.Parameter(torch.randn(n_out, n_in, num_grid) * 0.05)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B = x.size(0)
        x_e = x.unsqueeze(1).expand(B, self.n_out, self.n_in)
        coeff_e = self.coeffs.unsqueeze(0).expand(B, -1, -1, -1)
        sp = spline_interpolate(x_e, self.grid, coeff_e, spline_type=self.spline_type)
        y = sp.sum(dim=-1)
        return y


class KANAutoencoder(nn.Module):
    def __init__(self, H: int, W: int, latent_dim: int = 256, num_grid: int = 6, spline_type: str = "bspline"):
        super().__init__()
        self.H, self.W, self.latent_dim = H, W, latent_dim
        self.input_dim = H * W
        self.enc = KANLayer(self.input_dim, latent_dim, num_grid=num_grid, spline_type=spline_type)
        self.dec = nn.Sequential(
            KANLayer(latent_dim, self.input_dim, num_grid=num_grid, spline_type=spline_type),
            nn.Sigmoid(),
        )

    def forward(self, x: torch.Tensor):
        B = x.size(0)
        flat = x.view(B, -1)
        z = self.enc(flat)
        recon_flat = self.dec(z)
        recon = recon_flat.view(B, 1, self.H, self.W)
        return recon, z


# ====================================================
# FastKAN
# ====================================================

class FastKANAutoencoder(nn.Module):
    """
    Autoenkoder oparty o FastKAN: dwie sieci FastKAN (encoder i decoder).
    Wymaga zainstalowanej biblioteki fast-kan / fastkan. Jeśli brak, rzuci czytelny błąd przy inicjalizacji.
    """
    def __init__(self, H: int, W: int, latent_dim: int = 256):
        super().__init__()
        if FastKANModule is None:
            raise ImportError(
                "FastKAN nie jest zainstalowany. Zainstaluj: `pip install fast-kan` (lub `pip install fastkan`). "
                f"Szczegóły importu: {repr(_fastkan_import_error)}"
            )
        self.H, self.W = H, W
        input_dim = H * W
        # Prosta architektura: warstwa wej -> latent oraz latent -> wyjście.
        # (Biblioteka akceptuje listę rozmiarów warstw, podobnie jak w przykładzie z klasyfikacją.)
        self.enc = FastKANModule([input_dim, latent_dim])
        self.dec_core = FastKANModule([latent_dim, input_dim])
        self.dec_out = nn.Sigmoid()

    def forward(self, x: torch.Tensor):
        B = x.size(0)
        flat = x.view(B, -1)
        z = self.enc(flat)                    # [B, L]
        recon_flat = self.dec_out(self.dec_core(z))  # [B, H*W] -> [0,1]
        recon = recon_flat.view(B, 1, self.H, self.W)
        return recon, z


# ====================================================
# CNN
# ====================================================

class CNNAutoencoder(nn.Module):
    def __init__(self, H: int, W: int, latent_dim: int = 256, base_ch: int = 32):
        super().__init__()
        self.H, self.W, self.latent_dim = H, W, latent_dim
        min_hw = min(H, W)
        max_blocks = 4
        target_S = 8
        n_down = 0
        S = min_hw
        while S > target_S and n_down < max_blocks:
            S = (S + 1) // 2
            n_down += 1
        self.S = S

        # Encoder
        enc_layers: List[nn.Module] = []
        ch_in = 1
        ch = base_ch
        for _ in range(n_down):
            enc_layers += [
                nn.Conv2d(ch_in, ch, 3, 2, 1), nn.ReLU(inplace=True),
                nn.Conv2d(ch, ch, 3, 1, 1), nn.ReLU(inplace=True),
            ]
            ch_in = ch
            ch = min(4 * base_ch, ch * 2)
        self.encoder_cnn = nn.Sequential(*enc_layers) if enc_layers else nn.Identity()
        self.encoder_gap = nn.AdaptiveAvgPool2d(1)
        self.encoder_fc = nn.Linear(ch_in, latent_dim)

        # Decoder
        dec_ch = ch_in
        self.decoder_fc = nn.Linear(latent_dim, dec_ch * self.S * self.S)
        dec_layers: List[nn.Module] = []
        ch_in = dec_ch
        for _ in range(n_down):
            out_c = ch_in // 2 if ch_in > base_ch else base_ch
            dec_layers += [
                nn.ConvTranspose2d(ch_in, out_c, 3, 2, 1, output_padding=1), nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, 3, 1, 1), nn.ReLU(inplace=True),
            ]
            ch_in = out_c
        self.decoder_cnn = nn.Sequential(*dec_layers) if dec_layers else nn.Identity()
        self.decoder_out = nn.Sequential(nn.Conv2d(ch_in, 1, 3, 1, 1), nn.Sigmoid())

    def forward(self, x: torch.Tensor):
        h = self.encoder_cnn(x)
        gap = self.encoder_gap(h).flatten(1)
        z = self.encoder_fc(gap)
        d = self.decoder_fc(z).view(z.size(0), -1, self.S, self.S)
        d = self.decoder_cnn(d)
        recon = self.decoder_out(d)
        if recon.size(2) != self.H or recon.size(3) != self.W:
            recon = F.interpolate(recon, size=(self.H, self.W), mode="bilinear", align_corners=False)
        return recon, z


# ====================================================
# Zbiory danych (grayscale) + wrapper AEFromTorchvision
# ====================================================

class AEFromTorchvision(Dataset):
    """Owija dataset torchvision (x, label) -> (x, x) dla autoenkodera."""
    def __init__(self, base_ds: Dataset):
        super().__init__()
        self.base = base_ds
    def __len__(self):
        return len(self.base)
    def __getitem__(self, idx):
        item = self.base[idx]
        if isinstance(item, tuple) and len(item) >= 1:
            x = item[0]
        else:
            x = item
        return x, x


class ShapesDataset(Dataset):
    def __init__(self, n_samples: int = 1000, H: int = 64, W: int = 64, seed: int = 123):
        super().__init__()
        self.n = n_samples
        self.H, self.W = H, W
        rng = np.random.RandomState(seed)
        self.params = []
        for _ in range(n_samples):
            shape = rng.choice(["circle", "square", "triangle", "line"])
            cx, cy = rng.randint(8, W - 8), rng.randint(8, H - 8)
            size = rng.randint(6, max(7, min(H, W) // 3))
            angle = float(rng.rand() * 360.0)
            self.params.append((shape, cx, cy, size, angle))
    def __len__(self):
        return self.n
    def __getitem__(self, idx):
        import PIL.Image as Image
        import PIL.ImageDraw as ImageDraw
        shape, cx, cy, size, angle = self.params[idx]
        img = Image.new("L", (self.W, self.H), color=0)
        draw = ImageDraw.Draw(img)
        if shape == "circle":
            bbox = (cx - size, cy - size, cx + size, cy + size)
            draw.ellipse(bbox, fill=255, outline=255)
        elif shape == "square":
            bbox = (cx - size, cy - size, cx + size, cy + size)
            draw.rectangle(bbox, fill=255, outline=255)
        elif shape == "triangle":
            p1 = (cx, cy - size)
            p2 = (cx - size, cy + size)
            p3 = (cx + size, cy + size)
            ang = math.radians(angle)
            def rot(p):
                x, y = p
                xr = cx + (x - cx) * math.cos(ang) - (y - cy) * math.sin(ang)
                yr = cy + (x - cx) * math.sin(ang) + (y - cy) * math.cos(ang)
                return (xr, yr)
            poly = list(map(rot, [p1, p2, p3]))
            draw.polygon(poly, fill=255, outline=255)
        elif shape == "line":
            length = size * 2
            x1, y1 = cx - length // 2, cy
            x2, y2 = cx + length // 2, cy
            ang = math.radians(angle)
            def rot2(x, y):
                xr = cx + (x - cx) * math.cos(ang) - (y - cy) * math.sin(ang)
                yr = cy + (x - cx) * math.sin(ang) + (y - cy) * math.cos(ang)
                return (xr, yr)
            p1 = rot2(x1, y1); p2 = rot2(x2, y2)
            draw.line([p1, p2], fill=255, width=2)
        x = transforms.ToTensor()(img)
        return x, x

def plot_models_comparison_matplotlib(orig5: torch.Tensor,
                                      recons_by_model: Dict[str, torch.Tensor],
                                      order: List[str],
                                      title: str,
                                      out_png: str,
                                      show: bool = True,
                                      dpi: int = 120) -> None:
    """
    Rysuje planszę porównawczą w Matplotlib z podpisami:
    wiersz 0: 'original', kolejne: nazwy modeli z 'order' (jeśli dostępne).
    Zapisuje do out_png i (opcjonalnie) pokazuje w Jupyterze.
    """
    os.makedirs(os.path.dirname(out_png), exist_ok=True)
    # realna liczba wierszy (oryginał + te modele, które mamy)
    available = [m for m in order if m in recons_by_model]
    n_rows = 1 + len(available)
    n_cols = min(5, orig5.size(0))

    fig, axes = plt.subplots(n_rows, n_cols,
                             figsize=(n_cols * 2.4, n_rows * 2.4),
                             squeeze=False)

    # wiersz 0: oryginały
    for c in range(n_cols):
        img = orig5[c].detach().cpu().squeeze(0).numpy()
        ax = axes[0, c]
        ax.imshow(img, cmap="gray", vmin=0.0, vmax=1.0)
        ax.set_xticks([]); ax.set_yticks([])
        if c == 0:
            ax.set_ylabel("original", fontsize=10)
        ax.set_title(f"img {c+1}", fontsize=9)

    # kolejne wiersze: modele
    for r, name in enumerate(available, start=1):
        recs = recons_by_model[name]
        for c in range(n_cols):
            img = recs[c].detach().cpu().squeeze(0).numpy()
            ax = axes[r, c]
            ax.imshow(img, cmap="gray", vmin=0.0, vmax=1.0)
            ax.set_xticks([]); ax.set_yticks([])
            if c == 0:
                ax.set_ylabel(name, fontsize=10)

    if title:
        fig.suptitle(title, fontsize=12, y=0.995)
    plt.tight_layout()
    fig.savefig(out_png, bbox_inches="tight", dpi=dpi)
    if show:
        plt.show()
    plt.close(fig)

def get_loaders(dataset_name: str,
                data_root: str,
                batch_small: int = 64,
                batch_large: int = 16,
                large_resize_to: int = 64,
                custom_large_dir: Optional[str] = None) -> Tuple[DataLoader, DataLoader, Tuple[int, int]]:

    if dataset_name == "mnist":
        H, W = 28, 28
        tfm = transforms.ToTensor()
        
        g = torch.Generator().manual_seed(42)
        full_train = datasets.MNIST(root=data_root, train=True, download=True, transform=tfm)
        
        val_size = int(0.2 * len(full_train))
        train_size = len(full_train) - val_size
        base_train, base_test = random_split(full_train, [train_size, val_size], generator=g)

        train = AEFromTorchvision(base_train)
        test  = AEFromTorchvision(base_test)
        return (DataLoader(train, batch_size=batch_small, shuffle=True, num_workers=0),
                DataLoader(test,  batch_size=batch_small, shuffle=False, num_workers=0),
                (H, W))

    elif dataset_name == "cifar16":
        H, W = 16, 16
        tfm = transforms.Compose([
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize((H, W), interpolation=transforms.InterpolationMode.BICUBIC),
            transforms.ToTensor(),
        ])

        g = torch.Generator().manual_seed(42)
        full_train = datasets.CIFAR10(root=data_root, train=True, download=True, transform=tfm)

        val_size = int(0.2 * len(full_train))
        train_size = len(full_train) - val_size
        base_train, base_test = random_split(full_train, [train_size, val_size], generator=g)

        train = AEFromTorchvision(base_train)
        test  = AEFromTorchvision(base_test)
        return (DataLoader(train, batch_size=batch_small, shuffle=True, num_workers=0),
                DataLoader(test,  batch_size=batch_small, shuffle=False, num_workers=0),
                (H, W))

    elif dataset_name == "large":
        H = W = int(large_resize_to)
        if custom_large_dir and os.path.isdir(custom_large_dir):
            class FolderGray(Dataset):
                def __init__(self, root_dir: str, split: str = "train", val_ratio: float = 0.2):
                    files = []
                    for dirpath, _, filenames in os.walk(root_dir):
                        for fn in filenames:
                            if fn.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff")):
                                files.append(os.path.join(dirpath, fn))
                    files.sort()
                    n = len(files)
                    n_val = max(1, int(n * val_ratio))
                    self.files = files[:-n_val] if split == "train" else files[-n_val:]
                    self.tfm = transforms.Compose([
                        transforms.Grayscale(num_output_channels=1),
                        transforms.Resize((H, W), interpolation=transforms.InterpolationMode.BICUBIC),
                        transforms.ToTensor(),
                    ])
                def __len__(self): return len(self.files)
                def __getitem__(self, idx):
                    img = default_loader(self.files[idx])
                    x = self.tfm(img)
                    return x, x
            base_train = FolderGray(custom_large_dir, split="train")
            base_test  = FolderGray(custom_large_dir, split="val")
        else:
            tfm = transforms.Compose([
                transforms.Grayscale(num_output_channels=1),
                transforms.Resize((H, W), interpolation=transforms.InterpolationMode.BICUBIC),
                transforms.ToTensor(),
            ])
            g = torch.Generator().manual_seed(42)
            full_train = datasets.STL10(root=data_root, download=True, transform=tfm)
    
            val_size = int(0.2 * len(full_train))
            train_size = len(full_train) - val_size
            base_train, base_test = random_split(full_train, [train_size, val_size], generator=g)
        train = AEFromTorchvision(base_train)
        test  = AEFromTorchvision(base_test)
        return (DataLoader(train, batch_size=batch_large, shuffle=True, num_workers=0),
                DataLoader(test,  batch_size=batch_large, shuffle=False, num_workers=0),
                (H, W))

    elif dataset_name == "shapes":
        H, W = 32, 32
        train = ShapesDataset(n_samples=800, H=H, W=W, seed=42)
        test  = ShapesDataset(n_samples=200, H=H, W=W, seed=42)
        return (DataLoader(train, batch_size=batch_small, shuffle=True, num_workers=0),
                DataLoader(test,  batch_size=batch_small, shuffle=False, num_workers=0),
                (H, W))

    else:
        raise ValueError(f"Nieznany zbiór: {dataset_name}")


# ====================================================
# Trening / Ewaluacja
# ====================================================

@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, device: torch.device, max_batches: Optional[int] = None):
    model.eval()
    total_loss, n_seen = 0.0, 0
    psnrs, ssims = [], []
    for b_idx, (x, y) in enumerate(loader):
        x = x.to(device); y = y.to(device)
        recon, _ = model(x)
        total_loss += F.mse_loss(recon, y, reduction="sum").item()
        n_seen += x.size(0)
        p, s = psnr_ssim_batch(y, recon)
        psnrs.append(p); ssims.append(s)
        if max_batches is not None and (b_idx + 1) >= max_batches:
            break
    return total_loss / max(1, n_seen), float(np.mean(psnrs)), float(np.mean(ssims))


def train_one_epoch(model: nn.Module, loader: DataLoader, opt: torch.optim.Optimizer, device: torch.device):
    model.train()
    running = 0.0
    for x, y in loader:
        x = x.to(device); y = y.to(device)
        opt.zero_grad(set_to_none=True)
        recon, _ = model(x)
        loss = F.mse_loss(recon, y)
        loss.backward(); opt.step()
        running += loss.item() * x.size(0)
    return running / len(loader.dataset)


@torch.no_grad()
def measure_inference_time(model: nn.Module, loader: DataLoader, device: torch.device, warmup: int = 2, measure_batches: int = 5) -> float:
    model.eval()
    it = iter(loader)
    for _ in range(warmup):
        try:
            x, _ = next(it)
        except StopIteration:
            it = iter(loader); x, _ = next(it)
        x = x.to(device); _ = model(x)
    times = []
    it = iter(loader)
    for _ in range(measure_batches):
        try:
            x, _ = next(it)
        except StopIteration:
            it = iter(loader); x, _ = next(it)
        x = x.to(device)
        t0 = time.perf_counter(); _ = model(x); t1 = time.perf_counter()
        times.append((t1 - t0) / x.size(0))
    return float(np.mean(times))


# ====================================================
# Budowa modeli + zapis porównań obrazków
# ====================================================

def build_model(kind: str, H: int, W: int, latent_dim: int, kan_grid: int) -> nn.Module:
    if kind == "cnn":
        return CNNAutoencoder(H, W, latent_dim=latent_dim, base_ch=32)
    elif kind.startswith("kan_"):
        spline_map = {"kan_linear": "linear", "kan_bezier": "bezier", "kan_catmull": "catmull_rom", "kan_bspline": "bspline"}
        return KANAutoencoder(H, W, latent_dim=latent_dim, num_grid=kan_grid, spline_type=spline_map[kind])
    elif kind == "fastkan":
        return FastKANAutoencoder(H, W, latent_dim=latent_dim)
    else:
        raise ValueError(f"Nieznany model: {kind}")


def save_sample_recons(model: nn.Module, loader: DataLoader, device: torch.device, out_path: str, n_batches: int = 1):
    model.eval(); os.makedirs(os.path.dirname(out_path), exist_ok=True)
    imgs = []
    with torch.no_grad():
        it = iter(loader)
        for _ in range(n_batches):
            try: x, _ = next(it)
            except StopIteration: break
            x = x.to(device); recon, _ = model(x)
            grid = make_grid(torch.cat([x[:8], recon[:8]], dim=0), nrow=8)
            imgs.append(grid.cpu())
    if imgs: save_image(torch.stack(imgs).mean(dim=0), out_path)


def save_models_comparison(orig5: torch.Tensor,
                           recons_by_model: Dict[str, torch.Tensor],
                           order: List[str],
                           out_png: str,
                           legend_txt: str):
    """
    Tworzy wspólną planszę: pierwszy wiersz to oryginały (5 obrazków),
    kolejne wiersze to rekonstrukcje wg kolejności w 'order' (jeśli dostępne).
    Zapisuje PNG + plik z legendą.
    """
    os.makedirs(os.path.dirname(out_png), exist_ok=True)
    rows = []
    rows.append(make_grid(orig5[:5].cpu(), nrow=5, padding=2))
    legend_lines = ["Row 0: original"]
    row_idx = 1
    for name in order:
        if name in recons_by_model:
            rows.append(make_grid(recons_by_model[name][:5].cpu(), nrow=5, padding=2))
            legend_lines.append(f"Row {row_idx}: {name}")
            row_idx += 1
    if not rows:
        return
    hcat = rows[0]
    for r in rows[1:]:
        if r.shape[2] != hcat.shape[2]:
            # wycentruj/pad do tej samej szerokości
            W = max(r.shape[2], hcat.shape[2])
            def _pad_to(t, W):
                pad = W - t.shape[2]
                if pad <= 0: return t[:, :, :W]
                left = pad // 2; right = pad - left
                return F.pad(t, (left, right, 0, 0))
            hcat = _pad_to(hcat, W)
            r = _pad_to(r, W)
        hcat = torch.cat([hcat, r], dim=1)  # po wysokości
    save_image(hcat, out_png)
    with open(legend_txt, "w", encoding="utf-8") as f:
        f.write("\n".join(legend_lines))

def run_all(datasets: List[str] = None,
            models: List[str] = None,
            data_root: str = "./data",
            latent_dim: int = 256,
            kan_grid: int = 6,
            epochs_small: int = 10,
            epochs_large: int = 8,
            batch_small: int = 64,
            batch_large: int = 16,
            large_resize: int = 64,
            large_dir: Optional[str] = None,
            lr: float = 1e-3,
            max_eval_batches: Optional[int] = None,
            save_samples: bool = False,
            outdir: str = "./outputs",
            csv_path: str = "./outputs/results_equal_latent.csv",
            seed: int = 42) -> pd.DataFrame:

    set_seed(seed); device = torch.device("cpu"); os.makedirs(outdir, exist_ok=True)
    if datasets is None: datasets = ["mnist", "cifar16", "large", "shapes"]
    if models is None: models = ["cnn", "kan_linear", "kan_bezier", "kan_catmull", "kan_bspline", "fastkan"]

    print(models)

    results: List[Dict] = []

    for ds in datasets:
        train_loader, test_loader, (H, W) = get_loaders(
            ds, data_root,
            batch_small=batch_small,
            batch_large=batch_large,
            large_resize_to=large_resize,
            custom_large_dir=large_dir,
        )
        epochs = epochs_small if ds in ("mnist", "cifar16", "shapes") else epochs_large

        # 5 obrazów do porównań między modelami
        cmp_batch = next(iter(test_loader))[0][:5].to(device)  # [5,1,H,W]
        recons_by_model: Dict[str, torch.Tensor] = {}

        for kind in models:
            model = build_model(kind, H, W, latent_dim=latent_dim, kan_grid=kan_grid)
            model.to(device)
            n_params = count_params(model)
            opt = torch.optim.Adam(model.parameters(), lr=lr)
            best_val = float("inf"); best_state = None

            for ep in range(1, epochs + 1):
                tr_loss = train_one_epoch(model, train_loader, opt, device)
                val_loss, val_psnr, val_ssim = evaluate(model, test_loader, device, max_batches=max_eval_batches)
                if val_loss < best_val:
                    best_val = val_loss
                    best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                print(f"[{ds}][{kind}] ep {ep:03d}/{epochs} | train MSE {tr_loss:.5f} | val MSE {val_loss:.5f} | PSNR {val_psnr:.2f} dB | SSIM {val_ssim:.3f}")

            if best_state is not None: model.load_state_dict(best_state)
            val_loss, val_psnr, val_ssim = evaluate(model, test_loader, device, max_batches=max_eval_batches)
            sec_per_img = measure_inference_time(model, test_loader, device, warmup=2, measure_batches=5)

            # Zapisywanie próbki
            if save_samples:
                out_png = os.path.join(outdir, f"samples_{ds}_{kind}.png")
                save_sample_recons(model, test_loader, device, out_png, n_batches=1)

            # dodawanie rekonstrukcje do planszy
            with torch.no_grad():
                recon, _ = model(cmp_batch)
            recons_by_model[kind] = recon.detach().cpu()

            results.append({
                "dataset": ds,
                "H": H, "W": W,
                "model": kind,
                "latent_dim": latent_dim,
                "params": n_params,
                "epochs": epochs,
                "val_mse": val_loss,
                "val_psnr": val_psnr,
                "val_ssim": val_ssim,
                "infer_ms_per_img": sec_per_img * 1000.0,
            })
            del model

        # po przejściu wszystkich modeli dla danego zbioru — zapisz wspólną planszę porównawczą
        compare_png = os.path.join(outdir, f"compare_{ds}.png")
        compare_legend = os.path.join(outdir, f"compare_{ds}.txt")
        save_models_comparison(cmp_batch.cpu(), recons_by_model, models, compare_png, compare_legend)
        print(f"== Zapisano porównanie obrazów do: {compare_png} (legenda: {compare_legend})")

        # NOWE: Matplotlib z etykietami (pokazuje w Jupyterze + zapisuje)
        compare_mpl = os.path.join(outdir, f"compare_{ds}_mpl.png")
        plot_models_comparison_matplotlib(
            orig5=cmp_batch.cpu(),
            recons_by_model=recons_by_model,
            order=models,
            title=f"Dataset: {ds}  |  models: {', '.join([m for m in models if m in recons_by_model])}",
            out_png=compare_mpl,
            show=True,        # w Jupyterze wyświetli od razu
            dpi=120
        )
        print(f"== Zapisano porównanie Matplotlib do: {compare_mpl}")

    df = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df.to_csv(csv_path, index=False)
    print("\n== Zapisano wyniki do:", csv_path)
    print(df)
    return df


def parse_args_jupyter_friendly():
    parser = argparse.ArgumentParser(description="Porównanie AE: CNN, KAN (splajny), FastKAN — wspólny latent")
    parser.add_argument("--data-root", type=str, default="./data")
    parser.add_argument("--datasets", type=str, default="mnist,cifar16,large,shapes")
    parser.add_argument("--models", type=str, default="cnn,kan_linear,kan_bezier,kan_catmull,kan_bspline,fastkan")
    parser.add_argument("--latent-dim", type=int, default=16)
    parser.add_argument("--kan-grid", type=int, default=6)
    parser.add_argument("--epochs-small", type=int, default=10)
    parser.add_argument("--epochs-large", type=int, default=10)
    parser.add_argument("--batch-small", type=int, default=64)
    parser.add_argument("--batch-large", type=int, default=16)
    parser.add_argument("--large-resize", type=int, default=64)
    parser.add_argument("--large-dir", type=str, default=None)
    parser.add_argument("--lr", type=float, default=1e-3)
    parser.add_argument("--max-eval-batches", type=int, default=None)
    parser.add_argument("--save-samples", action="store_true")
    parser.add_argument("--outdir", type=str, default="./outputs")
    parser.add_argument("--csv", type=str, default="./outputs/results_equal_latent_16_no_silu_test.csv")
    parser.add_argument("--seed", type=int, default=42)
    args, _unknown = parser.parse_known_args()
    return args


latens = [256, 128, 64, 32, 16];

for lat in latens:
    run_all(
        datasets=["mnist","cifar16","large","shapes"],
        models=["cnn","kan_linear","kan_bezier","kan_catmull","kan_bspline","fastkan"],
        data_root="./data",
        latent_dim=lat,
        kan_grid=6,
        epochs_small=10,
        epochs_large=10,
        batch_small=64,
        batch_large=64,
        large_resize=64,
        large_dir=None,
        lr=1e-3,
        max_eval_batches=None,
        save_samples="store_true",
        outdir="./outputs",
        csv_path=f"./outputs/results_final_{lat}.csv",
        seed=42,
    )
# Out:
# /opt/anaconda3/envs/OE/lib/python3.12/site-packages/torchvision/io/image.py:14: UserWarning: Failed to load image Python extension: 'dlopen(/opt/anaconda3/envs/OE/lib/python3.12/site-packages/torchvision/image.so, 0x0006): Library not loaded: @rpath/libjpeg.9.dylib
#   Referenced from: <367D4265-B20F-34BD-94EB-4F3EE47C385B> /opt/anaconda3/envs/OE/lib/python3.12/site-packages/torchvision/image.so
#   Reason: tried: '/Users/sylwesterwieczorek/VulkanSDK/macOS/lib/libjpeg.9.dylib' (no such file), '/libjpeg.9.dylib' (no such file), '/opt/anaconda3/envs/OE/lib/python3.12/site-packages/torchvision/../../../libjpeg.9.dylib' (no such file), '/opt/anaconda3/envs/OE/lib/python3.12/site-packages/torchvision/../../../libjpeg.9.dylib' (no such file), '/opt/anaconda3/envs/OE/lib/python3.12/lib-dynload/../../libjpeg.9.dylib' (no such file), '/opt/anaconda3/envs/OE/bin/../lib/libjpeg.9.dylib' (no such file)'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ['cnn', 'kan_linear', 'kan_bezier', 'kan_catmull', 'kan_bspline', 'fastkan']
# [mnist][cnn] ep 001/10 | train MSE 0.04954 | val MSE 18.78598 | PSNR 16.91 dB | SSIM 0.746
# [mnist][cnn] ep 002/10 | train MSE 0.01805 | val MSE 11.16709 | PSNR 19.25 dB | SSIM 0.849
# [mnist][cnn] ep 003/10 | train MSE 0.01275 | val MSE 9.05995 | PSNR 20.08 dB | SSIM 0.876
# [mnist][cnn] ep 004/10 | train MSE 0.01044 | val MSE 7.67160 | PSNR 20.81 dB | SSIM 0.896
# [mnist][cnn] ep 005/10 | train MSE 0.00893 | val MSE 6.62932 | PSNR 21.55 dB | SSIM 0.910
# [mnist][cnn] ep 006/10 | train MSE 0.00799 | val MSE 5.96215 | PSNR 21.98 dB | SSIM 0.919
# [mnist][cnn] ep 007/10 | train MSE 0.00730 | val MSE 5.67616 | PSNR 22.14 dB | SSIM 0.919
# [mnist][cnn] ep 008/10 | train MSE 0.00677 | val MSE 5.30557 | PSNR 22.47 dB | SSIM 0.926
# [mnist][cnn] ep 009/10 | train MSE 0.00633 | val MSE 4.96060 | PSNR 22.73 dB | SSIM 0.931
# [mnist][cnn] ep 010/10 | train MSE 0.00597 | val MSE 4.72834 | PSNR 22.97 dB | SSIM 0.934
# [mnist][kan_linear] ep 001/10 | train MSE 0.02259 | val MSE 7.61438 | PSNR 20.70 dB | SSIM 0.778
# [mnist][kan_linear] ep 002/10 | train MSE 0.00738 | val MSE 4.63074 | PSNR 22.98 dB | SSIM 0.859
# [mnist][kan_linear] ep 003/10 | train MSE 0.00504 | val MSE 3.53418 | PSNR 24.17 dB | SSIM 0.877
# [mnist][kan_linear] ep 004/10 | train MSE 0.00394 | val MSE 2.85310 | PSNR 25.10 dB | SSIM 0.894
# [mnist][kan_linear] ep 005/10 | train MSE 0.00326 | val MSE 2.44968 | PSNR 25.78 dB | SSIM 0.910
# [mnist][kan_linear] ep 006/10 | train MSE 0.00281 | val MSE 2.18674 | PSNR 26.24 dB | SSIM 0.911
# [mnist][kan_linear] ep 007/10 | train MSE 0.00247 | val MSE 1.95673 | PSNR 26.71 dB | SSIM 0.918
# [mnist][kan_linear] ep 008/10 | train MSE 0.00222 | val MSE 1.81243 | PSNR 27.02 dB | SSIM 0.922
# [mnist][kan_linear] ep 009/10 | train MSE 0.00204 | val MSE 1.69642 | PSNR 27.30 dB | SSIM 0.922
# [mnist][kan_linear] ep 010/10 | train MSE 0.00187 | val MSE 1.58171 | PSNR 27.60 dB | SSIM 0.926
# [mnist][kan_bezier] ep 001/10 | train MSE 0.04296 | val MSE 21.03027 | PSNR 16.07 dB | SSIM 0.564
# [mnist][kan_bezier] ep 002/10 | train MSE 0.02191 | val MSE 14.30024 | PSNR 17.84 dB | SSIM 0.672
# [mnist][kan_bezier] ep 003/10 | train MSE 0.01576 | val MSE 10.83247 | PSNR 19.12 dB | SSIM 0.746
# [mnist][kan_bezier] ep 004/10 | train MSE 0.01250 | val MSE 8.85778 | PSNR 20.05 dB | SSIM 0.780
# [mnist][kan_bezier] ep 005/10 | train MSE 0.01047 | val MSE 7.73822 | PSNR 20.66 dB | SSIM 0.799
# [mnist][kan_bezier] ep 006/10 | train MSE 0.00906 | val MSE 6.67498 | PSNR 21.34 dB | SSIM 0.815
# [mnist][kan_bezier] ep 007/10 | train MSE 0.00802 | val MSE 6.11350 | PSNR 21.71 dB | SSIM 0.846
# [mnist][kan_bezier] ep 008/10 | train MSE 0.00724 | val MSE 5.45656 | PSNR 22.23 dB | SSIM 0.851
# [mnist][kan_bezier] ep 009/10 | train MSE 0.00662 | val MSE 5.07752 | PSNR 22.57 dB | SSIM 0.868
# [mnist][kan_bezier] ep 010/10 | train MSE 0.00610 | val MSE 4.69431 | PSNR 22.90 dB | SSIM 0.874
# [mnist][kan_catmull] ep 001/10 | train MSE 0.02964 | val MSE 11.38884 | PSNR 18.86 dB | SSIM 0.694
# [mnist][kan_catmull] ep 002/10 | train MSE 0.01113 | val MSE 6.92895 | PSNR 21.12 dB | SSIM 0.786
# [mnist][kan_catmull] ep 003/10 | train MSE 0.00754 | val MSE 5.13777 | PSNR 22.47 dB | SSIM 0.833
# [mnist][kan_catmull] ep 004/10 | train MSE 0.00587 | val MSE 4.25314 | PSNR 23.31 dB | SSIM 0.845
# [mnist][kan_catmull] ep 005/10 | train MSE 0.00488 | val MSE 3.57735 | PSNR 24.09 dB | SSIM 0.875
# [mnist][kan_catmull] ep 006/10 | train MSE 0.00422 | val MSE 3.21099 | PSNR 24.53 dB | SSIM 0.879
# [mnist][kan_catmull] ep 007/10 | train MSE 0.00373 | val MSE 2.84100 | PSNR 25.07 dB | SSIM 0.901
# [mnist][kan_catmull] ep 008/10 | train MSE 0.00337 | val MSE 2.66794 | PSNR 25.31 dB | SSIM 0.906
# [mnist][kan_catmull] ep 009/10 | train MSE 0.00309 | val MSE 2.43026 | PSNR 25.74 dB | SSIM 0.903
# [mnist][kan_catmull] ep 010/10 | train MSE 0.00287 | val MSE 2.18631 | PSNR 26.23 dB | SSIM 0.916
# [mnist][kan_bspline] ep 001/10 | train MSE 0.04390 | val MSE 21.81483 | PSNR 15.92 dB | SSIM 0.557
# [mnist][kan_bspline] ep 002/10 | train MSE 0.02258 | val MSE 14.54938 | PSNR 17.80 dB | SSIM 0.678
# [mnist][kan_bspline] ep 003/10 | train MSE 0.01598 | val MSE 10.87177 | PSNR 19.16 dB | SSIM 0.743
# [mnist][kan_bspline] ep 004/10 | train MSE 0.01249 | val MSE 9.01173 | PSNR 20.00 dB | SSIM 0.788
# [mnist][kan_bspline] ep 005/10 | train MSE 0.01037 | val MSE 7.56904 | PSNR 20.80 dB | SSIM 0.802
# [mnist][kan_bspline] ep 006/10 | train MSE 0.00892 | val MSE 6.65325 | PSNR 21.39 dB | SSIM 0.837
# [mnist][kan_bspline] ep 007/10 | train MSE 0.00789 | val MSE 5.84680 | PSNR 21.97 dB | SSIM 0.844
# [mnist][kan_bspline] ep 008/10 | train MSE 0.00710 | val MSE 5.36394 | PSNR 22.35 dB | SSIM 0.859
# [mnist][kan_bspline] ep 009/10 | train MSE 0.00647 | val MSE 4.91012 | PSNR 22.74 dB | SSIM 0.869
# [mnist][kan_bspline] ep 010/10 | train MSE 0.00597 | val MSE 4.57346 | PSNR 23.06 dB | SSIM 0.876
# [mnist][fastkan] ep 001/10 | train MSE 0.01805 | val MSE 5.62283 | PSNR 22.14 dB | SSIM 0.888
# [mnist][fastkan] ep 002/10 | train MSE 0.00561 | val MSE 3.56745 | PSNR 24.25 dB | SSIM 0.917
# [mnist][fastkan] ep 003/10 | train MSE 0.00389 | val MSE 2.80144 | PSNR 25.34 dB | SSIM 0.928
# [mnist][fastkan] ep 004/10 | train MSE 0.00322 | val MSE 2.46227 | PSNR 25.95 dB | SSIM 0.936
# [mnist][fastkan] ep 005/10 | train MSE 0.00283 | val MSE 2.18604 | PSNR 26.53 dB | SSIM 0.937
# [mnist][fastkan] ep 006/10 | train MSE 0.00256 | val MSE 1.99515 | PSNR 26.95 dB | SSIM 0.938
# [mnist][fastkan] ep 007/10 | train MSE 0.00235 | val MSE 1.92472 | PSNR 27.11 dB | SSIM 0.940
# [mnist][fastkan] ep 008/10 | train MSE 0.00223 | val MSE 1.83718 | PSNR 27.36 dB | SSIM 0.941
# [mnist][fastkan] ep 009/10 | train MSE 0.00212 | val MSE 1.70956 | PSNR 27.75 dB | SSIM 0.943
# [mnist][fastkan] ep 010/10 | train MSE 0.00204 | val MSE 1.64920 | PSNR 27.96 dB | SSIM 0.943
# == Zapisano porównanie obrazów do: ./outputs/compare_mnist.png (legenda: ./outputs/compare_mnist.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_mnist_mpl.png
# Files already downloaded and verified
# [cifar16][cnn] ep 001/10 | train MSE 0.02757 | val MSE 5.31817 | PSNR 17.57 dB | SSIM 0.350
# [cifar16][cnn] ep 002/10 | train MSE 0.01840 | val MSE 4.37189 | PSNR 18.42 dB | SSIM 0.451
# [cifar16][cnn] ep 003/10 | train MSE 0.01602 | val MSE 3.88232 | PSNR 18.95 dB | SSIM 0.504
# [cifar16][cnn] ep 004/10 | train MSE 0.01469 | val MSE 3.62783 | PSNR 19.24 dB | SSIM 0.534
# [cifar16][cnn] ep 005/10 | train MSE 0.01404 | val MSE 3.52258 | PSNR 19.36 dB | SSIM 0.549
# [cifar16][cnn] ep 006/10 | train MSE 0.01350 | val MSE 3.41747 | PSNR 19.47 dB | SSIM 0.560
# [cifar16][cnn] ep 007/10 | train MSE 0.01308 | val MSE 3.27155 | PSNR 19.66 dB | SSIM 0.576
# [cifar16][cnn] ep 008/10 | train MSE 0.01267 | val MSE 3.27565 | PSNR 19.64 dB | SSIM 0.579
# [cifar16][cnn] ep 009/10 | train MSE 0.01241 | val MSE 3.13316 | PSNR 19.85 dB | SSIM 0.586
# [cifar16][cnn] ep 010/10 | train MSE 0.01215 | val MSE 3.17442 | PSNR 19.75 dB | SSIM 0.589
# [cifar16][kan_linear] ep 001/10 | train MSE 0.01435 | val MSE 1.88692 | PSNR 22.03 dB | SSIM 0.783
# [cifar16][kan_linear] ep 002/10 | train MSE 0.00575 | val MSE 1.18180 | PSNR 24.03 dB | SSIM 0.872
# [cifar16][kan_linear] ep 003/10 | train MSE 0.00393 | val MSE 0.87974 | PSNR 25.30 dB | SSIM 0.906
# [cifar16][kan_linear] ep 004/10 | train MSE 0.00302 | val MSE 0.70403 | PSNR 26.27 dB | SSIM 0.927
# [cifar16][kan_linear] ep 005/10 | train MSE 0.00248 | val MSE 0.58616 | PSNR 27.08 dB | SSIM 0.941
# [cifar16][kan_linear] ep 006/10 | train MSE 0.00211 | val MSE 0.52602 | PSNR 27.48 dB | SSIM 0.947
# [cifar16][kan_linear] ep 007/10 | train MSE 0.00185 | val MSE 0.46714 | PSNR 27.99 dB | SSIM 0.953
# [cifar16][kan_linear] ep 008/10 | train MSE 0.00165 | val MSE 0.40332 | PSNR 28.70 dB | SSIM 0.960
# [cifar16][kan_linear] ep 009/10 | train MSE 0.00149 | val MSE 0.37908 | PSNR 28.91 dB | SSIM 0.963
# [cifar16][kan_linear] ep 010/10 | train MSE 0.00136 | val MSE 0.34957 | PSNR 29.26 dB | SSIM 0.965
# [cifar16][kan_bezier] ep 001/10 | train MSE 0.02823 | val MSE 4.76102 | PSNR 18.08 dB | SSIM 0.410
# [cifar16][kan_bezier] ep 002/10 | train MSE 0.01555 | val MSE 3.45550 | PSNR 19.43 dB | SSIM 0.573
# [cifar16][kan_bezier] ep 003/10 | train MSE 0.01225 | val MSE 2.81594 | PSNR 20.28 dB | SSIM 0.662
# [cifar16][kan_bezier] ep 004/10 | train MSE 0.01022 | val MSE 2.42133 | PSNR 20.93 dB | SSIM 0.715
# [cifar16][kan_bezier] ep 005/10 | train MSE 0.00892 | val MSE 2.12937 | PSNR 21.48 dB | SSIM 0.756
# [cifar16][kan_bezier] ep 006/10 | train MSE 0.00792 | val MSE 1.90269 | PSNR 21.96 dB | SSIM 0.784
# [cifar16][kan_bezier] ep 007/10 | train MSE 0.00712 | val MSE 1.72394 | PSNR 22.38 dB | SSIM 0.808
# [cifar16][kan_bezier] ep 008/10 | train MSE 0.00650 | val MSE 1.57965 | PSNR 22.76 dB | SSIM 0.826
# [cifar16][kan_bezier] ep 009/10 | train MSE 0.00600 | val MSE 1.46894 | PSNR 23.07 dB | SSIM 0.839
# [cifar16][kan_bezier] ep 010/10 | train MSE 0.00558 | val MSE 1.37968 | PSNR 23.32 dB | SSIM 0.851
# [cifar16][kan_catmull] ep 001/10 | train MSE 0.01884 | val MSE 2.80866 | PSNR 20.29 dB | SSIM 0.663
# [cifar16][kan_catmull] ep 002/10 | train MSE 0.00904 | val MSE 1.92916 | PSNR 21.89 dB | SSIM 0.784
# [cifar16][kan_catmull] ep 003/10 | train MSE 0.00671 | val MSE 1.51280 | PSNR 22.93 dB | SSIM 0.839
# [cifar16][kan_catmull] ep 004/10 | train MSE 0.00547 | val MSE 1.27765 | PSNR 23.65 dB | SSIM 0.868
# [cifar16][kan_catmull] ep 005/10 | train MSE 0.00465 | val MSE 1.11603 | PSNR 24.22 dB | SSIM 0.886
# [cifar16][kan_catmull] ep 006/10 | train MSE 0.00411 | val MSE 0.99504 | PSNR 24.71 dB | SSIM 0.900
# [cifar16][kan_catmull] ep 007/10 | train MSE 0.00369 | val MSE 0.90357 | PSNR 25.12 dB | SSIM 0.910
# [cifar16][kan_catmull] ep 008/10 | train MSE 0.00338 | val MSE 0.90242 | PSNR 25.02 dB | SSIM 0.916
# [cifar16][kan_catmull] ep 009/10 | train MSE 0.00313 | val MSE 0.79773 | PSNR 25.63 dB | SSIM 0.925
# [cifar16][kan_catmull] ep 010/10 | train MSE 0.00292 | val MSE 0.72744 | PSNR 26.05 dB | SSIM 0.931
# [cifar16][kan_bspline] ep 001/10 | train MSE 0.02606 | val MSE 4.25048 | PSNR 18.56 dB | SSIM 0.471
# [cifar16][kan_bspline] ep 002/10 | train MSE 0.01436 | val MSE 3.21657 | PSNR 19.72 dB | SSIM 0.604
# [cifar16][kan_bspline] ep 003/10 | train MSE 0.01138 | val MSE 2.67261 | PSNR 20.50 dB | SSIM 0.679
# [cifar16][kan_bspline] ep 004/10 | train MSE 0.00973 | val MSE 2.31565 | PSNR 21.13 dB | SSIM 0.730
# [cifar16][kan_bspline] ep 005/10 | train MSE 0.00857 | val MSE 2.07004 | PSNR 21.59 dB | SSIM 0.761
# [cifar16][kan_bspline] ep 006/10 | train MSE 0.00768 | val MSE 1.86861 | PSNR 22.02 dB | SSIM 0.788
# [cifar16][kan_bspline] ep 007/10 | train MSE 0.00696 | val MSE 1.70011 | PSNR 22.44 dB | SSIM 0.810
# [cifar16][kan_bspline] ep 008/10 | train MSE 0.00638 | val MSE 1.57473 | PSNR 22.76 dB | SSIM 0.825
# [cifar16][kan_bspline] ep 009/10 | train MSE 0.00591 | val MSE 1.45268 | PSNR 23.12 dB | SSIM 0.839
# [cifar16][kan_bspline] ep 010/10 | train MSE 0.00550 | val MSE 1.36660 | PSNR 23.37 dB | SSIM 0.850
# [cifar16][fastkan] ep 001/10 | train MSE 0.01802 | val MSE 2.09718 | PSNR 21.19 dB | SSIM 0.798
# [cifar16][fastkan] ep 002/10 | train MSE 0.00638 | val MSE 1.32804 | PSNR 23.23 dB | SSIM 0.868
# [cifar16][fastkan] ep 003/10 | train MSE 0.00453 | val MSE 1.02889 | PSNR 24.39 dB | SSIM 0.896
# [cifar16][fastkan] ep 004/10 | train MSE 0.00358 | val MSE 0.85164 | PSNR 25.23 dB | SSIM 0.912
# [cifar16][fastkan] ep 005/10 | train MSE 0.00300 | val MSE 0.72995 | PSNR 25.92 dB | SSIM 0.925
# [cifar16][fastkan] ep 006/10 | train MSE 0.00259 | val MSE 0.63378 | PSNR 26.57 dB | SSIM 0.935
# [cifar16][fastkan] ep 007/10 | train MSE 0.00230 | val MSE 0.57588 | PSNR 26.98 dB | SSIM 0.942
# [cifar16][fastkan] ep 008/10 | train MSE 0.00208 | val MSE 0.52985 | PSNR 27.34 dB | SSIM 0.946
# [cifar16][fastkan] ep 009/10 | train MSE 0.00191 | val MSE 0.47926 | PSNR 27.80 dB | SSIM 0.950
# [cifar16][fastkan] ep 010/10 | train MSE 0.00177 | val MSE 0.43644 | PSNR 28.25 dB | SSIM 0.954
# == Zapisano porównanie obrazów do: ./outputs/compare_cifar16.png (legenda: ./outputs/compare_cifar16.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_cifar16_mpl.png
# Files already downloaded and verified
# [large][cnn] ep 001/10 | train MSE 0.05791 | val MSE 220.69397 | PSNR 13.36 dB | SSIM 0.192
# [large][cnn] ep 002/10 | train MSE 0.05083 | val MSE 195.98615 | PSNR 13.88 dB | SSIM 0.197
# [large][cnn] ep 003/10 | train MSE 0.04049 | val MSE 158.53914 | PSNR 14.73 dB | SSIM 0.200
# [large][cnn] ep 004/10 | train MSE 0.03610 | val MSE 145.22648 | PSNR 15.15 dB | SSIM 0.211
# [large][cnn] ep 005/10 | train MSE 0.03383 | val MSE 134.74555 | PSNR 15.45 dB | SSIM 0.222
# [large][cnn] ep 006/10 | train MSE 0.03125 | val MSE 120.53899 | PSNR 15.90 dB | SSIM 0.234
# [large][cnn] ep 007/10 | train MSE 0.02852 | val MSE 112.16691 | PSNR 16.24 dB | SSIM 0.246
# [large][cnn] ep 008/10 | train MSE 0.02736 | val MSE 110.44460 | PSNR 16.30 dB | SSIM 0.250
# [large][cnn] ep 009/10 | train MSE 0.02685 | val MSE 108.20490 | PSNR 16.39 dB | SSIM 0.255
# [large][cnn] ep 010/10 | train MSE 0.02600 | val MSE 104.58330 | PSNR 16.52 dB | SSIM 0.261
# [large][kan_linear] ep 001/10 | train MSE 0.05208 | val MSE 164.63314 | PSNR 14.50 dB | SSIM 0.127
# [large][kan_linear] ep 002/10 | train MSE 0.03534 | val MSE 132.89935 | PSNR 15.47 dB | SSIM 0.160
# [large][kan_linear] ep 003/10 | train MSE 0.03031 | val MSE 120.02004 | PSNR 15.87 dB | SSIM 0.186
# [large][kan_linear] ep 004/10 | train MSE 0.02747 | val MSE 108.60287 | PSNR 16.33 dB | SSIM 0.202
# [large][kan_linear] ep 005/10 | train MSE 0.02570 | val MSE 105.94575 | PSNR 16.37 dB | SSIM 0.215
# [large][kan_linear] ep 006/10 | train MSE 0.02385 | val MSE 96.65084 | PSNR 16.82 dB | SSIM 0.234
# [large][kan_linear] ep 007/10 | train MSE 0.02265 | val MSE 93.65747 | PSNR 16.93 dB | SSIM 0.245
# [large][kan_linear] ep 008/10 | train MSE 0.02183 | val MSE 90.48667 | PSNR 17.09 dB | SSIM 0.254
# [large][kan_linear] ep 009/10 | train MSE 0.02084 | val MSE 91.17889 | PSNR 16.99 dB | SSIM 0.263
# [large][kan_linear] ep 010/10 | train MSE 0.02032 | val MSE 85.22792 | PSNR 17.34 dB | SSIM 0.274
# [large][kan_bezier] ep 001/10 | train MSE 0.05577 | val MSE 179.69190 | PSNR 14.18 dB | SSIM 0.149
# [large][kan_bezier] ep 002/10 | train MSE 0.03810 | val MSE 144.11792 | PSNR 15.15 dB | SSIM 0.178
# [large][kan_bezier] ep 003/10 | train MSE 0.03367 | val MSE 131.25815 | PSNR 15.52 dB | SSIM 0.186
# [large][kan_bezier] ep 004/10 | train MSE 0.03046 | val MSE 119.70947 | PSNR 15.90 dB | SSIM 0.202
# [large][kan_bezier] ep 005/10 | train MSE 0.02804 | val MSE 111.79178 | PSNR 16.20 dB | SSIM 0.215
# [large][kan_bezier] ep 006/10 | train MSE 0.02662 | val MSE 108.32227 | PSNR 16.33 dB | SSIM 0.221
# [large][kan_bezier] ep 007/10 | train MSE 0.02600 | val MSE 104.97895 | PSNR 16.45 dB | SSIM 0.227
# [large][kan_bezier] ep 008/10 | train MSE 0.02486 | val MSE 104.45576 | PSNR 16.43 dB | SSIM 0.231
# [large][kan_bezier] ep 009/10 | train MSE 0.02383 | val MSE 100.10227 | PSNR 16.62 dB | SSIM 0.235
# [large][kan_bezier] ep 010/10 | train MSE 0.02314 | val MSE 95.18311 | PSNR 16.86 dB | SSIM 0.249
# [large][kan_catmull] ep 001/10 | train MSE 0.05536 | val MSE 179.00005 | PSNR 14.14 dB | SSIM 0.132
# [large][kan_catmull] ep 002/10 | train MSE 0.03837 | val MSE 148.30829 | PSNR 14.98 dB | SSIM 0.161
# [large][kan_catmull] ep 003/10 | train MSE 0.03345 | val MSE 133.86929 | PSNR 15.40 dB | SSIM 0.181
# [large][kan_catmull] ep 004/10 | train MSE 0.03052 | val MSE 121.50085 | PSNR 15.82 dB | SSIM 0.199
# [large][kan_catmull] ep 005/10 | train MSE 0.02826 | val MSE 115.24774 | PSNR 16.05 dB | SSIM 0.207
# [large][kan_catmull] ep 006/10 | train MSE 0.02743 | val MSE 111.39114 | PSNR 16.18 dB | SSIM 0.217
# [large][kan_catmull] ep 007/10 | train MSE 0.02605 | val MSE 108.07424 | PSNR 16.30 dB | SSIM 0.226
# [large][kan_catmull] ep 008/10 | train MSE 0.02479 | val MSE 102.98370 | PSNR 16.52 dB | SSIM 0.235
# [large][kan_catmull] ep 009/10 | train MSE 0.02443 | val MSE 98.81205 | PSNR 16.71 dB | SSIM 0.243
# [large][kan_catmull] ep 010/10 | train MSE 0.02321 | val MSE 95.44461 | PSNR 16.86 dB | SSIM 0.252
# [large][kan_bspline] ep 001/10 | train MSE 0.05469 | val MSE 177.19807 | PSNR 14.25 dB | SSIM 0.153
# [large][kan_bspline] ep 002/10 | train MSE 0.03823 | val MSE 147.47235 | PSNR 15.04 dB | SSIM 0.172
# [large][kan_bspline] ep 003/10 | train MSE 0.03430 | val MSE 135.25420 | PSNR 15.38 dB | SSIM 0.186
# [large][kan_bspline] ep 004/10 | train MSE 0.03092 | val MSE 122.45514 | PSNR 15.80 dB | SSIM 0.203
# [large][kan_bspline] ep 005/10 | train MSE 0.02839 | val MSE 114.53700 | PSNR 16.10 dB | SSIM 0.213
# [large][kan_bspline] ep 006/10 | train MSE 0.02717 | val MSE 110.44181 | PSNR 16.26 dB | SSIM 0.219
# [large][kan_bspline] ep 007/10 | train MSE 0.02626 | val MSE 106.97906 | PSNR 16.39 dB | SSIM 0.223
# [large][kan_bspline] ep 008/10 | train MSE 0.02555 | val MSE 104.93158 | PSNR 16.45 dB | SSIM 0.226
# [large][kan_bspline] ep 009/10 | train MSE 0.02464 | val MSE 100.25578 | PSNR 16.66 dB | SSIM 0.239
# [large][kan_bspline] ep 010/10 | train MSE 0.02377 | val MSE 97.34237 | PSNR 16.78 dB | SSIM 0.244
# [large][fastkan] ep 001/10 | train MSE 0.06865 | val MSE 166.73879 | PSNR 14.31 dB | SSIM 0.099
# [large][fastkan] ep 002/10 | train MSE 0.03488 | val MSE 130.51990 | PSNR 15.40 dB | SSIM 0.140
# [large][fastkan] ep 003/10 | train MSE 0.02936 | val MSE 116.43682 | PSNR 15.89 dB | SSIM 0.169
# [large][fastkan] ep 004/10 | train MSE 0.02641 | val MSE 106.57307 | PSNR 16.28 dB | SSIM 0.191
# [large][fastkan] ep 005/10 | train MSE 0.02425 | val MSE 99.78757 | PSNR 16.55 dB | SSIM 0.209
# [large][fastkan] ep 006/10 | train MSE 0.02256 | val MSE 94.38771 | PSNR 16.80 dB | SSIM 0.226
# [large][fastkan] ep 007/10 | train MSE 0.02123 | val MSE 89.44226 | PSNR 17.03 dB | SSIM 0.243
# [large][fastkan] ep 008/10 | train MSE 0.02006 | val MSE 86.19688 | PSNR 17.17 dB | SSIM 0.254
# [large][fastkan] ep 009/10 | train MSE 0.01909 | val MSE 83.02566 | PSNR 17.34 dB | SSIM 0.267
# [large][fastkan] ep 010/10 | train MSE 0.01819 | val MSE 80.17283 | PSNR 17.49 dB | SSIM 0.279
# == Zapisano porównanie obrazów do: ./outputs/compare_large.png (legenda: ./outputs/compare_large.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_large_mpl.png
# [shapes][cnn] ep 001/10 | train MSE 0.22520 | val MSE 142.92089 | PSNR 9.96 dB | SSIM 0.116
# [shapes][cnn] ep 002/10 | train MSE 0.12893 | val MSE 118.68957 | PSNR 10.16 dB | SSIM 0.166
# [shapes][cnn] ep 003/10 | train MSE 0.11308 | val MSE 116.20054 | PSNR 10.13 dB | SSIM 0.128
# [shapes][cnn] ep 004/10 | train MSE 0.11105 | val MSE 113.78800 | PSNR 10.16 dB | SSIM 0.076
# [shapes][cnn] ep 005/10 | train MSE 0.10872 | val MSE 110.84567 | PSNR 10.54 dB | SSIM 0.059
# [shapes][cnn] ep 006/10 | train MSE 0.10592 | val MSE 107.99390 | PSNR 10.76 dB | SSIM 0.066
# [shapes][cnn] ep 007/10 | train MSE 0.10308 | val MSE 105.42932 | PSNR 10.96 dB | SSIM 0.080
# [shapes][cnn] ep 008/10 | train MSE 0.10043 | val MSE 102.90122 | PSNR 11.19 dB | SSIM 0.076
# [shapes][cnn] ep 009/10 | train MSE 0.09777 | val MSE 100.68177 | PSNR 11.43 dB | SSIM 0.092
# [shapes][cnn] ep 010/10 | train MSE 0.09640 | val MSE 100.28705 | PSNR 11.43 dB | SSIM 0.096
# [shapes][kan_linear] ep 001/10 | train MSE 0.14686 | val MSE 102.58978 | PSNR 10.66 dB | SSIM 0.051
# [shapes][kan_linear] ep 002/10 | train MSE 0.08809 | val MSE 76.30620 | PSNR 11.98 dB | SSIM 0.092
# [shapes][kan_linear] ep 003/10 | train MSE 0.06366 | val MSE 56.25882 | PSNR 13.23 dB | SSIM 0.131
# [shapes][kan_linear] ep 004/10 | train MSE 0.04871 | val MSE 44.79298 | PSNR 14.08 dB | SSIM 0.167
# [shapes][kan_linear] ep 005/10 | train MSE 0.04038 | val MSE 38.44015 | PSNR 14.62 dB | SSIM 0.212
# [shapes][kan_linear] ep 006/10 | train MSE 0.03549 | val MSE 34.48662 | PSNR 14.99 dB | SSIM 0.260
# [shapes][kan_linear] ep 007/10 | train MSE 0.03227 | val MSE 31.38627 | PSNR 15.36 dB | SSIM 0.302
# [shapes][kan_linear] ep 008/10 | train MSE 0.02983 | val MSE 29.32471 | PSNR 15.61 dB | SSIM 0.334
# [shapes][kan_linear] ep 009/10 | train MSE 0.02799 | val MSE 27.81959 | PSNR 15.79 dB | SSIM 0.359
# [shapes][kan_linear] ep 010/10 | train MSE 0.02668 | val MSE 26.34974 | PSNR 16.03 dB | SSIM 0.385
# [shapes][kan_bezier] ep 001/10 | train MSE 0.14427 | val MSE 113.06508 | PSNR 10.33 dB | SSIM 0.041
# [shapes][kan_bezier] ep 002/10 | train MSE 0.10817 | val MSE 110.79960 | PSNR 10.32 dB | SSIM 0.049
# [shapes][kan_bezier] ep 003/10 | train MSE 0.10511 | val MSE 106.09896 | PSNR 10.50 dB | SSIM 0.052
# [shapes][kan_bezier] ep 004/10 | train MSE 0.09873 | val MSE 95.91080 | PSNR 10.84 dB | SSIM 0.064
# [shapes][kan_bezier] ep 005/10 | train MSE 0.08595 | val MSE 80.05684 | PSNR 11.60 dB | SSIM 0.084
# [shapes][kan_bezier] ep 006/10 | train MSE 0.07059 | val MSE 65.40329 | PSNR 12.49 dB | SSIM 0.110
# [shapes][kan_bezier] ep 007/10 | train MSE 0.05812 | val MSE 55.17174 | PSNR 13.28 dB | SSIM 0.133
# [shapes][kan_bezier] ep 008/10 | train MSE 0.05044 | val MSE 49.44190 | PSNR 13.73 dB | SSIM 0.163
# [shapes][kan_bezier] ep 009/10 | train MSE 0.04579 | val MSE 45.97839 | PSNR 13.99 dB | SSIM 0.192
# [shapes][kan_bezier] ep 010/10 | train MSE 0.04314 | val MSE 43.85361 | PSNR 14.17 dB | SSIM 0.218
# [shapes][kan_catmull] ep 001/10 | train MSE 0.14579 | val MSE 109.76768 | PSNR 10.38 dB | SSIM 0.044
# [shapes][kan_catmull] ep 002/10 | train MSE 0.10014 | val MSE 94.58515 | PSNR 11.02 dB | SSIM 0.066
# [shapes][kan_catmull] ep 003/10 | train MSE 0.08192 | val MSE 72.91326 | PSNR 12.17 dB | SSIM 0.097
# [shapes][kan_catmull] ep 004/10 | train MSE 0.06254 | val MSE 57.44656 | PSNR 13.20 dB | SSIM 0.128
# [shapes][kan_catmull] ep 005/10 | train MSE 0.05116 | val MSE 48.55953 | PSNR 13.84 dB | SSIM 0.158
# [shapes][kan_catmull] ep 006/10 | train MSE 0.04435 | val MSE 43.32725 | PSNR 14.21 dB | SSIM 0.179
# [shapes][kan_catmull] ep 007/10 | train MSE 0.03998 | val MSE 39.29452 | PSNR 14.57 dB | SSIM 0.214
# [shapes][kan_catmull] ep 008/10 | train MSE 0.03671 | val MSE 36.48604 | PSNR 14.83 dB | SSIM 0.244
# [shapes][kan_catmull] ep 009/10 | train MSE 0.03439 | val MSE 34.42601 | PSNR 15.04 dB | SSIM 0.265
# [shapes][kan_catmull] ep 010/10 | train MSE 0.03259 | val MSE 32.61596 | PSNR 15.24 dB | SSIM 0.289
# [shapes][kan_bspline] ep 001/10 | train MSE 0.14665 | val MSE 112.67642 | PSNR 10.29 dB | SSIM 0.042
# [shapes][kan_bspline] ep 002/10 | train MSE 0.10753 | val MSE 109.74862 | PSNR 10.32 dB | SSIM 0.052
# [shapes][kan_bspline] ep 003/10 | train MSE 0.10396 | val MSE 104.46954 | PSNR 10.55 dB | SSIM 0.055
# [shapes][kan_bspline] ep 004/10 | train MSE 0.09616 | val MSE 93.26756 | PSNR 10.98 dB | SSIM 0.067
# [shapes][kan_bspline] ep 005/10 | train MSE 0.08351 | val MSE 77.99664 | PSNR 11.74 dB | SSIM 0.086
# [shapes][kan_bspline] ep 006/10 | train MSE 0.06974 | val MSE 65.53044 | PSNR 12.54 dB | SSIM 0.107
# [shapes][kan_bspline] ep 007/10 | train MSE 0.05858 | val MSE 56.09885 | PSNR 13.18 dB | SSIM 0.130
# [shapes][kan_bspline] ep 008/10 | train MSE 0.05118 | val MSE 50.24133 | PSNR 13.62 dB | SSIM 0.152
# [shapes][kan_bspline] ep 009/10 | train MSE 0.04636 | val MSE 45.79542 | PSNR 14.00 dB | SSIM 0.179
# [shapes][kan_bspline] ep 010/10 | train MSE 0.04306 | val MSE 43.40902 | PSNR 14.20 dB | SSIM 0.206
# [shapes][fastkan] ep 001/10 | train MSE 0.14115 | val MSE 81.54959 | PSNR 11.96 dB | SSIM 0.161
# [shapes][fastkan] ep 002/10 | train MSE 0.06360 | val MSE 52.41501 | PSNR 13.65 dB | SSIM 0.322
# [shapes][fastkan] ep 003/10 | train MSE 0.04507 | val MSE 40.70738 | PSNR 14.56 dB | SSIM 0.471
# [shapes][fastkan] ep 004/10 | train MSE 0.03616 | val MSE 34.11903 | PSNR 15.22 dB | SSIM 0.533
# [shapes][fastkan] ep 005/10 | train MSE 0.03106 | val MSE 30.19393 | PSNR 15.68 dB | SSIM 0.568
# [shapes][fastkan] ep 006/10 | train MSE 0.02777 | val MSE 27.32253 | PSNR 16.11 dB | SSIM 0.597
# [shapes][fastkan] ep 007/10 | train MSE 0.02552 | val MSE 25.49618 | PSNR 16.39 dB | SSIM 0.613
# [shapes][fastkan] ep 008/10 | train MSE 0.02394 | val MSE 24.04717 | PSNR 16.65 dB | SSIM 0.630
# [shapes][fastkan] ep 009/10 | train MSE 0.02252 | val MSE 22.35378 | PSNR 16.97 dB | SSIM 0.641
# [shapes][fastkan] ep 010/10 | train MSE 0.02124 | val MSE 21.12239 | PSNR 17.24 dB | SSIM 0.649
# == Zapisano porównanie obrazów do: ./outputs/compare_shapes.png (legenda: ./outputs/compare_shapes.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_shapes_mpl.png
#
# == Zapisano wyniki do: ./outputs/results_final_256.csv
#     dataset   H   W        model  latent_dim    params  epochs     val_mse  \
# 0     mnist  28  28          cnn         256    934081      10    4.728342
# 1     mnist  28  28   kan_linear         256   2408448      10    1.581712
# 2     mnist  28  28   kan_bezier         256   2408448      10    4.694310
# 3     mnist  28  28  kan_catmull         256   2408448      10    2.186314
# 4     mnist  28  28  kan_bspline         256   2408448      10    4.573457
# 5     mnist  28  28      fastkan         256   3615808      10    1.649201
# 6   cifar16  16  16          cnn         256    563137      10    3.133164
# 7   cifar16  16  16   kan_linear         256    786432      10    0.349566
# 8   cifar16  16  16   kan_bezier         256    786432      10    1.379684
# 9   cifar16  16  16  kan_catmull         256    786432      10    0.727440
# 10  cifar16  16  16  kan_bspline         256    786432      10    1.366598
# 11  cifar16  16  16      fastkan         256   1181200      10    0.436444
# 12    large  64  64          cnn         256   2582017      10  104.583300
# 13    large  64  64   kan_linear         256  12582912      10   85.227924
# 14    large  64  64   kan_bezier         256  12582912      10   95.183114
# 15    large  64  64  kan_catmull         256  12582912      10   95.444611
# 16    large  64  64  kan_bspline         256  12582912      10   97.342372
# 17    large  64  64      fastkan         256  18887440      10   80.172827
# 18   shapes  32  32          cnn         256   1180801      10  100.287052
# 19   shapes  32  32   kan_linear         256   3145728      10   26.349744
# 20   shapes  32  32   kan_bezier         256   3145728      10   43.853606
# 21   shapes  32  32  kan_catmull         256   3145728      10   32.615959
# 22   shapes  32  32  kan_bspline         256   3145728      10   43.409018
# 23   shapes  32  32      fastkan         256   4722448      10   21.122391
#
#      val_psnr  val_ssim  infer_ms_per_img
# 0   22.972124  0.933879          0.622825
# 1   27.600971  0.925532          1.325107
# 2   22.903792  0.873973          6.092899
# 3   26.227463  0.915997          4.835662
# 4   23.062983  0.876313          4.494480
# 5   27.956977  0.942573          0.036410
# 6   19.854294  0.586467          0.134312
# 7   29.259190  0.965302          0.392944
# 8   23.322661  0.850878          1.258990
# 9   26.046311  0.931155          1.444655
# 10  23.372699  0.849789          1.567526
# 11  28.250914  0.954090          0.018450
# 12  16.524399  0.260599          2.753297
# 13  17.341886  0.273503         10.155790
# 14  16.860767  0.248597         22.929079
# 15  16.856535  0.252283         31.093117
# 16  16.780214  0.243725         31.117554
# 17  17.489565  0.278943          0.136574
# 18  11.434147  0.096317          0.640177
# 19  16.031396  0.385056          1.482428
# 20  14.172622  0.218446          5.796500
# 21  15.242498  0.289029          6.061764
# 22  14.196896  0.205796          6.244746
# 23  17.239068  0.648959          0.107463
# ['cnn', 'kan_linear', 'kan_bezier', 'kan_catmull', 'kan_bspline', 'fastkan']
# [mnist][cnn] ep 001/10 | train MSE 0.05574 | val MSE 23.04151 | PSNR 15.92 dB | SSIM 0.675
# [mnist][cnn] ep 002/10 | train MSE 0.02112 | val MSE 13.35435 | PSNR 18.34 dB | SSIM 0.816
# [mnist][cnn] ep 003/10 | train MSE 0.01410 | val MSE 9.99367 | PSNR 19.75 dB | SSIM 0.864
# [mnist][cnn] ep 004/10 | train MSE 0.01135 | val MSE 8.24567 | PSNR 20.57 dB | SSIM 0.888
# [mnist][cnn] ep 005/10 | train MSE 0.00967 | val MSE 7.19882 | PSNR 21.17 dB | SSIM 0.902
# [mnist][cnn] ep 006/10 | train MSE 0.00857 | val MSE 6.33708 | PSNR 21.77 dB | SSIM 0.913
# [mnist][cnn] ep 007/10 | train MSE 0.00782 | val MSE 6.01189 | PSNR 21.99 dB | SSIM 0.919
# [mnist][cnn] ep 008/10 | train MSE 0.00719 | val MSE 5.30718 | PSNR 22.57 dB | SSIM 0.927
# [mnist][cnn] ep 009/10 | train MSE 0.00674 | val MSE 5.20648 | PSNR 22.57 dB | SSIM 0.927
# [mnist][cnn] ep 010/10 | train MSE 0.00629 | val MSE 4.69143 | PSNR 23.10 dB | SSIM 0.935
# [mnist][kan_linear] ep 001/10 | train MSE 0.02896 | val MSE 10.95444 | PSNR 19.08 dB | SSIM 0.711
# [mnist][kan_linear] ep 002/10 | train MSE 0.01102 | val MSE 7.01320 | PSNR 21.14 dB | SSIM 0.792
# [mnist][kan_linear] ep 003/10 | train MSE 0.00778 | val MSE 5.45287 | PSNR 22.27 dB | SSIM 0.839
# [mnist][kan_linear] ep 004/10 | train MSE 0.00618 | val MSE 4.49652 | PSNR 23.15 dB | SSIM 0.862
# [mnist][kan_linear] ep 005/10 | train MSE 0.00518 | val MSE 3.87311 | PSNR 23.80 dB | SSIM 0.873
# [mnist][kan_linear] ep 006/10 | train MSE 0.00447 | val MSE 3.48757 | PSNR 24.23 dB | SSIM 0.880
# [mnist][kan_linear] ep 007/10 | train MSE 0.00395 | val MSE 3.08621 | PSNR 24.78 dB | SSIM 0.892
# [mnist][kan_linear] ep 008/10 | train MSE 0.00355 | val MSE 2.76789 | PSNR 25.28 dB | SSIM 0.901
# [mnist][kan_linear] ep 009/10 | train MSE 0.00323 | val MSE 2.59061 | PSNR 25.55 dB | SSIM 0.906
# [mnist][kan_linear] ep 010/10 | train MSE 0.00298 | val MSE 2.42392 | PSNR 25.84 dB | SSIM 0.905
# [mnist][kan_bezier] ep 001/10 | train MSE 0.04720 | val MSE 24.37981 | PSNR 15.38 dB | SSIM 0.494
# [mnist][kan_bezier] ep 002/10 | train MSE 0.02635 | val MSE 17.63117 | PSNR 16.91 dB | SSIM 0.614
# [mnist][kan_bezier] ep 003/10 | train MSE 0.01989 | val MSE 13.98349 | PSNR 17.98 dB | SSIM 0.676
# [mnist][kan_bezier] ep 004/10 | train MSE 0.01613 | val MSE 11.62415 | PSNR 18.81 dB | SSIM 0.723
# [mnist][kan_bezier] ep 005/10 | train MSE 0.01378 | val MSE 10.21263 | PSNR 19.43 dB | SSIM 0.762
# [mnist][kan_bezier] ep 006/10 | train MSE 0.01212 | val MSE 8.91209 | PSNR 20.06 dB | SSIM 0.782
# [mnist][kan_bezier] ep 007/10 | train MSE 0.01086 | val MSE 8.13745 | PSNR 20.47 dB | SSIM 0.796
# [mnist][kan_bezier] ep 008/10 | train MSE 0.00991 | val MSE 7.45986 | PSNR 20.86 dB | SSIM 0.814
# [mnist][kan_bezier] ep 009/10 | train MSE 0.00912 | val MSE 6.93586 | PSNR 21.21 dB | SSIM 0.829
# [mnist][kan_bezier] ep 010/10 | train MSE 0.00847 | val MSE 6.51570 | PSNR 21.48 dB | SSIM 0.842
# [mnist][kan_catmull] ep 001/10 | train MSE 0.03536 | val MSE 14.94144 | PSNR 17.65 dB | SSIM 0.619
# [mnist][kan_catmull] ep 002/10 | train MSE 0.01509 | val MSE 9.55307 | PSNR 19.71 dB | SSIM 0.720
# [mnist][kan_catmull] ep 003/10 | train MSE 0.01054 | val MSE 7.25056 | PSNR 20.97 dB | SSIM 0.780
# [mnist][kan_catmull] ep 004/10 | train MSE 0.00832 | val MSE 6.00892 | PSNR 21.81 dB | SSIM 0.810
# [mnist][kan_catmull] ep 005/10 | train MSE 0.00696 | val MSE 5.07556 | PSNR 22.58 dB | SSIM 0.835
# [mnist][kan_catmull] ep 006/10 | train MSE 0.00604 | val MSE 4.55507 | PSNR 23.05 dB | SSIM 0.858
# [mnist][kan_catmull] ep 007/10 | train MSE 0.00536 | val MSE 4.01486 | PSNR 23.63 dB | SSIM 0.865
# [mnist][kan_catmull] ep 008/10 | train MSE 0.00485 | val MSE 3.75074 | PSNR 23.90 dB | SSIM 0.869
# [mnist][kan_catmull] ep 009/10 | train MSE 0.00442 | val MSE 3.40482 | PSNR 24.33 dB | SSIM 0.880
# [mnist][kan_catmull] ep 010/10 | train MSE 0.00409 | val MSE 3.16573 | PSNR 24.64 dB | SSIM 0.888
# [mnist][kan_bspline] ep 001/10 | train MSE 0.04814 | val MSE 24.64169 | PSNR 15.38 dB | SSIM 0.500
# [mnist][kan_bspline] ep 002/10 | train MSE 0.02572 | val MSE 16.82793 | PSNR 17.17 dB | SSIM 0.627
# [mnist][kan_bspline] ep 003/10 | train MSE 0.01878 | val MSE 13.11852 | PSNR 18.31 dB | SSIM 0.698
# [mnist][kan_bspline] ep 004/10 | train MSE 0.01518 | val MSE 10.89261 | PSNR 19.16 dB | SSIM 0.747
# [mnist][kan_bspline] ep 005/10 | train MSE 0.01291 | val MSE 9.49144 | PSNR 19.78 dB | SSIM 0.773
# [mnist][kan_bspline] ep 006/10 | train MSE 0.01132 | val MSE 8.46351 | PSNR 20.30 dB | SSIM 0.798
# [mnist][kan_bspline] ep 007/10 | train MSE 0.01010 | val MSE 7.57356 | PSNR 20.80 dB | SSIM 0.810
# [mnist][kan_bspline] ep 008/10 | train MSE 0.00916 | val MSE 6.92843 | PSNR 21.21 dB | SSIM 0.828
# [mnist][kan_bspline] ep 009/10 | train MSE 0.00839 | val MSE 6.40229 | PSNR 21.57 dB | SSIM 0.846
# [mnist][kan_bspline] ep 010/10 | train MSE 0.00778 | val MSE 5.91355 | PSNR 21.92 dB | SSIM 0.851
# [mnist][fastkan] ep 001/10 | train MSE 0.02081 | val MSE 6.18973 | PSNR 21.64 dB | SSIM 0.865
# [mnist][fastkan] ep 002/10 | train MSE 0.00598 | val MSE 3.80089 | PSNR 23.81 dB | SSIM 0.910
# [mnist][fastkan] ep 003/10 | train MSE 0.00414 | val MSE 3.00540 | PSNR 24.83 dB | SSIM 0.921
# [mnist][fastkan] ep 004/10 | train MSE 0.00333 | val MSE 2.50200 | PSNR 25.65 dB | SSIM 0.932
# [mnist][fastkan] ep 005/10 | train MSE 0.00286 | val MSE 2.23887 | PSNR 26.13 dB | SSIM 0.934
# [mnist][fastkan] ep 006/10 | train MSE 0.00257 | val MSE 2.06614 | PSNR 26.47 dB | SSIM 0.938
# [mnist][fastkan] ep 007/10 | train MSE 0.00237 | val MSE 1.91021 | PSNR 26.84 dB | SSIM 0.939
# [mnist][fastkan] ep 008/10 | train MSE 0.00222 | val MSE 1.82289 | PSNR 27.04 dB | SSIM 0.941
# [mnist][fastkan] ep 009/10 | train MSE 0.00210 | val MSE 1.74365 | PSNR 27.23 dB | SSIM 0.943
# [mnist][fastkan] ep 010/10 | train MSE 0.00200 | val MSE 1.69070 | PSNR 27.36 dB | SSIM 0.945
# == Zapisano porównanie obrazów do: ./outputs/compare_mnist.png (legenda: ./outputs/compare_mnist.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_mnist_mpl.png
# Files already downloaded and verified
# [cifar16][cnn] ep 001/10 | train MSE 0.02656 | val MSE 5.03541 | PSNR 17.88 dB | SSIM 0.380
# [cifar16][cnn] ep 002/10 | train MSE 0.01806 | val MSE 4.36781 | PSNR 18.42 dB | SSIM 0.459
# [cifar16][cnn] ep 003/10 | train MSE 0.01580 | val MSE 3.79627 | PSNR 19.07 dB | SSIM 0.523
# [cifar16][cnn] ep 004/10 | train MSE 0.01453 | val MSE 3.55206 | PSNR 19.33 dB | SSIM 0.547
# [cifar16][cnn] ep 005/10 | train MSE 0.01369 | val MSE 3.39923 | PSNR 19.52 dB | SSIM 0.567
# [cifar16][cnn] ep 006/10 | train MSE 0.01307 | val MSE 3.27194 | PSNR 19.67 dB | SSIM 0.578
# [cifar16][cnn] ep 007/10 | train MSE 0.01268 | val MSE 3.17606 | PSNR 19.80 dB | SSIM 0.591
# [cifar16][cnn] ep 008/10 | train MSE 0.01229 | val MSE 3.08819 | PSNR 19.92 dB | SSIM 0.598
# [cifar16][cnn] ep 009/10 | train MSE 0.01200 | val MSE 3.01262 | PSNR 20.03 dB | SSIM 0.603
# [cifar16][cnn] ep 010/10 | train MSE 0.01176 | val MSE 3.02380 | PSNR 19.98 dB | SSIM 0.605
# [cifar16][kan_linear] ep 001/10 | train MSE 0.01626 | val MSE 2.30498 | PSNR 21.21 dB | SSIM 0.729
# [cifar16][kan_linear] ep 002/10 | train MSE 0.00727 | val MSE 1.52690 | PSNR 22.97 dB | SSIM 0.831
# [cifar16][kan_linear] ep 003/10 | train MSE 0.00520 | val MSE 1.17655 | PSNR 24.10 dB | SSIM 0.873
# [cifar16][kan_linear] ep 004/10 | train MSE 0.00416 | val MSE 0.97689 | PSNR 24.89 dB | SSIM 0.897
# [cifar16][kan_linear] ep 005/10 | train MSE 0.00351 | val MSE 0.83788 | PSNR 25.57 dB | SSIM 0.913
# [cifar16][kan_linear] ep 006/10 | train MSE 0.00306 | val MSE 0.74107 | PSNR 26.09 dB | SSIM 0.924
# [cifar16][kan_linear] ep 007/10 | train MSE 0.00272 | val MSE 0.66625 | PSNR 26.55 dB | SSIM 0.932
# [cifar16][kan_linear] ep 008/10 | train MSE 0.00246 | val MSE 0.61594 | PSNR 26.86 dB | SSIM 0.938
# [cifar16][kan_linear] ep 009/10 | train MSE 0.00226 | val MSE 0.55951 | PSNR 27.31 dB | SSIM 0.944
# [cifar16][kan_linear] ep 010/10 | train MSE 0.00209 | val MSE 0.53150 | PSNR 27.50 dB | SSIM 0.947
# [cifar16][kan_bezier] ep 001/10 | train MSE 0.02909 | val MSE 5.10341 | PSNR 17.82 dB | SSIM 0.379
# [cifar16][kan_bezier] ep 002/10 | train MSE 0.01688 | val MSE 3.76713 | PSNR 19.10 dB | SSIM 0.536
# [cifar16][kan_bezier] ep 003/10 | train MSE 0.01354 | val MSE 3.12544 | PSNR 19.88 dB | SSIM 0.618
# [cifar16][kan_bezier] ep 004/10 | train MSE 0.01137 | val MSE 2.70065 | PSNR 20.50 dB | SSIM 0.680
# [cifar16][kan_bezier] ep 005/10 | train MSE 0.01005 | val MSE 2.43029 | PSNR 20.95 dB | SSIM 0.716
# [cifar16][kan_bezier] ep 006/10 | train MSE 0.00911 | val MSE 2.22149 | PSNR 21.32 dB | SSIM 0.746
# [cifar16][kan_bezier] ep 007/10 | train MSE 0.00831 | val MSE 2.02862 | PSNR 21.71 dB | SSIM 0.770
# [cifar16][kan_bezier] ep 008/10 | train MSE 0.00763 | val MSE 1.87995 | PSNR 22.03 dB | SSIM 0.790
# [cifar16][kan_bezier] ep 009/10 | train MSE 0.00708 | val MSE 1.74981 | PSNR 22.34 dB | SSIM 0.807
# [cifar16][kan_bezier] ep 010/10 | train MSE 0.00663 | val MSE 1.64397 | PSNR 22.61 dB | SSIM 0.819
# [cifar16][kan_catmull] ep 001/10 | train MSE 0.02036 | val MSE 3.18076 | PSNR 19.79 dB | SSIM 0.619
# [cifar16][kan_catmull] ep 002/10 | train MSE 0.01047 | val MSE 2.29692 | PSNR 21.17 dB | SSIM 0.741
# [cifar16][kan_catmull] ep 003/10 | train MSE 0.00806 | val MSE 1.86619 | PSNR 22.05 dB | SSIM 0.796
# [cifar16][kan_catmull] ep 004/10 | train MSE 0.00673 | val MSE 1.58562 | PSNR 22.77 dB | SSIM 0.831
# [cifar16][kan_catmull] ep 005/10 | train MSE 0.00585 | val MSE 1.39369 | PSNR 23.32 dB | SSIM 0.855
# [cifar16][kan_catmull] ep 006/10 | train MSE 0.00521 | val MSE 1.26900 | PSNR 23.71 dB | SSIM 0.871
# [cifar16][kan_catmull] ep 007/10 | train MSE 0.00474 | val MSE 1.15421 | PSNR 24.12 dB | SSIM 0.884
# [cifar16][kan_catmull] ep 008/10 | train MSE 0.00435 | val MSE 1.06829 | PSNR 24.46 dB | SSIM 0.894
# [cifar16][kan_catmull] ep 009/10 | train MSE 0.00405 | val MSE 1.01411 | PSNR 24.65 dB | SSIM 0.900
# [cifar16][kan_catmull] ep 010/10 | train MSE 0.00380 | val MSE 0.94793 | PSNR 24.95 dB | SSIM 0.908
# [cifar16][kan_bspline] ep 001/10 | train MSE 0.02756 | val MSE 4.81254 | PSNR 18.04 dB | SSIM 0.403
# [cifar16][kan_bspline] ep 002/10 | train MSE 0.01597 | val MSE 3.64976 | PSNR 19.20 dB | SSIM 0.551
# [cifar16][kan_bspline] ep 003/10 | train MSE 0.01292 | val MSE 2.99504 | PSNR 20.06 dB | SSIM 0.633
# [cifar16][kan_bspline] ep 004/10 | train MSE 0.01093 | val MSE 2.63036 | PSNR 20.59 dB | SSIM 0.686
# [cifar16][kan_bspline] ep 005/10 | train MSE 0.00973 | val MSE 2.35945 | PSNR 21.07 dB | SSIM 0.724
# [cifar16][kan_bspline] ep 006/10 | train MSE 0.00881 | val MSE 2.14671 | PSNR 21.47 dB | SSIM 0.752
# [cifar16][kan_bspline] ep 007/10 | train MSE 0.00805 | val MSE 1.96646 | PSNR 21.85 dB | SSIM 0.776
# [cifar16][kan_bspline] ep 008/10 | train MSE 0.00743 | val MSE 1.81915 | PSNR 22.19 dB | SSIM 0.795
# [cifar16][kan_bspline] ep 009/10 | train MSE 0.00691 | val MSE 1.71261 | PSNR 22.43 dB | SSIM 0.810
# [cifar16][kan_bspline] ep 010/10 | train MSE 0.00646 | val MSE 1.60483 | PSNR 22.71 dB | SSIM 0.823
# [cifar16][fastkan] ep 001/10 | train MSE 0.01788 | val MSE 2.28914 | PSNR 20.88 dB | SSIM 0.771
# [cifar16][fastkan] ep 002/10 | train MSE 0.00728 | val MSE 1.57052 | PSNR 22.56 dB | SSIM 0.841
# [cifar16][fastkan] ep 003/10 | train MSE 0.00536 | val MSE 1.22096 | PSNR 23.67 dB | SSIM 0.877
# [cifar16][fastkan] ep 004/10 | train MSE 0.00431 | val MSE 1.01604 | PSNR 24.49 dB | SSIM 0.896
# [cifar16][fastkan] ep 005/10 | train MSE 0.00362 | val MSE 0.87003 | PSNR 25.18 dB | SSIM 0.911
# [cifar16][fastkan] ep 006/10 | train MSE 0.00316 | val MSE 0.76911 | PSNR 25.73 dB | SSIM 0.921
# [cifar16][fastkan] ep 007/10 | train MSE 0.00283 | val MSE 0.68736 | PSNR 26.25 dB | SSIM 0.930
# [cifar16][fastkan] ep 008/10 | train MSE 0.00259 | val MSE 0.64017 | PSNR 26.55 dB | SSIM 0.934
# [cifar16][fastkan] ep 009/10 | train MSE 0.00241 | val MSE 0.60048 | PSNR 26.82 dB | SSIM 0.938
# [cifar16][fastkan] ep 010/10 | train MSE 0.00227 | val MSE 0.57298 | PSNR 27.03 dB | SSIM 0.940
# == Zapisano porównanie obrazów do: ./outputs/compare_cifar16.png (legenda: ./outputs/compare_cifar16.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_cifar16_mpl.png
# Files already downloaded and verified
# [large][cnn] ep 001/10 | train MSE 0.05804 | val MSE 220.84129 | PSNR 13.40 dB | SSIM 0.190
# [large][cnn] ep 002/10 | train MSE 0.04983 | val MSE 189.27374 | PSNR 14.02 dB | SSIM 0.198
# [large][cnn] ep 003/10 | train MSE 0.04093 | val MSE 153.18780 | PSNR 14.90 dB | SSIM 0.200
# [large][cnn] ep 004/10 | train MSE 0.03609 | val MSE 144.76579 | PSNR 15.16 dB | SSIM 0.211
# [large][cnn] ep 005/10 | train MSE 0.03291 | val MSE 124.58072 | PSNR 15.78 dB | SSIM 0.230
# [large][cnn] ep 006/10 | train MSE 0.02944 | val MSE 116.16612 | PSNR 16.05 dB | SSIM 0.240
# [large][cnn] ep 007/10 | train MSE 0.02766 | val MSE 112.23016 | PSNR 16.20 dB | SSIM 0.245
# [large][cnn] ep 008/10 | train MSE 0.02668 | val MSE 108.94261 | PSNR 16.33 dB | SSIM 0.256
# [large][cnn] ep 009/10 | train MSE 0.02550 | val MSE 101.81921 | PSNR 16.64 dB | SSIM 0.268
# [large][cnn] ep 010/10 | train MSE 0.02429 | val MSE 99.29942 | PSNR 16.73 dB | SSIM 0.274
# [large][kan_linear] ep 001/10 | train MSE 0.05340 | val MSE 172.87687 | PSNR 14.31 dB | SSIM 0.131
# [large][kan_linear] ep 002/10 | train MSE 0.03743 | val MSE 143.27817 | PSNR 15.16 dB | SSIM 0.161
# [large][kan_linear] ep 003/10 | train MSE 0.03259 | val MSE 126.88064 | PSNR 15.68 dB | SSIM 0.181
# [large][kan_linear] ep 004/10 | train MSE 0.02973 | val MSE 118.88784 | PSNR 15.94 dB | SSIM 0.199
# [large][kan_linear] ep 005/10 | train MSE 0.02767 | val MSE 115.21623 | PSNR 16.03 dB | SSIM 0.212
# [large][kan_linear] ep 006/10 | train MSE 0.02616 | val MSE 109.65363 | PSNR 16.25 dB | SSIM 0.221
# [large][kan_linear] ep 007/10 | train MSE 0.02497 | val MSE 103.32807 | PSNR 16.52 dB | SSIM 0.235
# [large][kan_linear] ep 008/10 | train MSE 0.02409 | val MSE 97.70017 | PSNR 16.80 dB | SSIM 0.243
# [large][kan_linear] ep 009/10 | train MSE 0.02307 | val MSE 99.51114 | PSNR 16.64 dB | SSIM 0.248
# [large][kan_linear] ep 010/10 | train MSE 0.02252 | val MSE 95.37066 | PSNR 16.85 dB | SSIM 0.258
# [large][kan_bezier] ep 001/10 | train MSE 0.05604 | val MSE 192.53899 | PSNR 13.88 dB | SSIM 0.151
# [large][kan_bezier] ep 002/10 | train MSE 0.04037 | val MSE 151.45656 | PSNR 14.93 dB | SSIM 0.174
# [large][kan_bezier] ep 003/10 | train MSE 0.03512 | val MSE 139.34196 | PSNR 15.29 dB | SSIM 0.192
# [large][kan_bezier] ep 004/10 | train MSE 0.03232 | val MSE 125.60189 | PSNR 15.73 dB | SSIM 0.202
# [large][kan_bezier] ep 005/10 | train MSE 0.02959 | val MSE 117.54352 | PSNR 16.00 dB | SSIM 0.212
# [large][kan_bezier] ep 006/10 | train MSE 0.02790 | val MSE 112.99972 | PSNR 16.18 dB | SSIM 0.221
# [large][kan_bezier] ep 007/10 | train MSE 0.02710 | val MSE 112.54256 | PSNR 16.16 dB | SSIM 0.224
# [large][kan_bezier] ep 008/10 | train MSE 0.02630 | val MSE 108.36476 | PSNR 16.33 dB | SSIM 0.229
# [large][kan_bezier] ep 009/10 | train MSE 0.02575 | val MSE 105.66831 | PSNR 16.44 dB | SSIM 0.234
# [large][kan_bezier] ep 010/10 | train MSE 0.02504 | val MSE 102.92112 | PSNR 16.56 dB | SSIM 0.240
# [large][kan_catmull] ep 001/10 | train MSE 0.05594 | val MSE 186.28762 | PSNR 14.05 dB | SSIM 0.144
# [large][kan_catmull] ep 002/10 | train MSE 0.04073 | val MSE 162.19497 | PSNR 14.59 dB | SSIM 0.168
# [large][kan_catmull] ep 003/10 | train MSE 0.03627 | val MSE 144.08731 | PSNR 15.11 dB | SSIM 0.183
# [large][kan_catmull] ep 004/10 | train MSE 0.03348 | val MSE 136.29976 | PSNR 15.34 dB | SSIM 0.190
# [large][kan_catmull] ep 005/10 | train MSE 0.03137 | val MSE 126.89203 | PSNR 15.64 dB | SSIM 0.199
# [large][kan_catmull] ep 006/10 | train MSE 0.02953 | val MSE 119.14543 | PSNR 15.94 dB | SSIM 0.211
# [large][kan_catmull] ep 007/10 | train MSE 0.02810 | val MSE 113.93868 | PSNR 16.14 dB | SSIM 0.219
# [large][kan_catmull] ep 008/10 | train MSE 0.02744 | val MSE 111.45903 | PSNR 16.21 dB | SSIM 0.223
# [large][kan_catmull] ep 009/10 | train MSE 0.02644 | val MSE 108.06241 | PSNR 16.35 dB | SSIM 0.232
# [large][kan_catmull] ep 010/10 | train MSE 0.02546 | val MSE 106.19556 | PSNR 16.40 dB | SSIM 0.237
# [large][kan_bspline] ep 001/10 | train MSE 0.05572 | val MSE 187.16092 | PSNR 14.01 dB | SSIM 0.153
# [large][kan_bspline] ep 002/10 | train MSE 0.04033 | val MSE 153.86084 | PSNR 14.87 dB | SSIM 0.180
# [large][kan_bspline] ep 003/10 | train MSE 0.03559 | val MSE 141.93815 | PSNR 15.23 dB | SSIM 0.191
# [large][kan_bspline] ep 004/10 | train MSE 0.03324 | val MSE 132.00167 | PSNR 15.50 dB | SSIM 0.198
# [large][kan_bspline] ep 005/10 | train MSE 0.03083 | val MSE 121.94597 | PSNR 15.85 dB | SSIM 0.208
# [large][kan_bspline] ep 006/10 | train MSE 0.02881 | val MSE 115.55251 | PSNR 16.09 dB | SSIM 0.217
# [large][kan_bspline] ep 007/10 | train MSE 0.02749 | val MSE 111.62944 | PSNR 16.24 dB | SSIM 0.223
# [large][kan_bspline] ep 008/10 | train MSE 0.02681 | val MSE 109.57668 | PSNR 16.30 dB | SSIM 0.229
# [large][kan_bspline] ep 009/10 | train MSE 0.02611 | val MSE 107.75761 | PSNR 16.37 dB | SSIM 0.230
# [large][kan_bspline] ep 010/10 | train MSE 0.02559 | val MSE 105.58148 | PSNR 16.45 dB | SSIM 0.233
# [large][fastkan] ep 001/10 | train MSE 0.06620 | val MSE 178.31659 | PSNR 14.02 dB | SSIM 0.098
# [large][fastkan] ep 002/10 | train MSE 0.03734 | val MSE 139.65671 | PSNR 15.15 dB | SSIM 0.132
# [large][fastkan] ep 003/10 | train MSE 0.03123 | val MSE 122.51541 | PSNR 15.71 dB | SSIM 0.162
# [large][fastkan] ep 004/10 | train MSE 0.02803 | val MSE 112.92533 | PSNR 16.07 dB | SSIM 0.181
# [large][fastkan] ep 005/10 | train MSE 0.02586 | val MSE 105.49706 | PSNR 16.35 dB | SSIM 0.199
# [large][fastkan] ep 006/10 | train MSE 0.02408 | val MSE 99.37481 | PSNR 16.60 dB | SSIM 0.215
# [large][fastkan] ep 007/10 | train MSE 0.02267 | val MSE 94.79686 | PSNR 16.80 dB | SSIM 0.229
# [large][fastkan] ep 008/10 | train MSE 0.02152 | val MSE 90.99576 | PSNR 16.98 dB | SSIM 0.242
# [large][fastkan] ep 009/10 | train MSE 0.02051 | val MSE 87.57868 | PSNR 17.14 dB | SSIM 0.253
# [large][fastkan] ep 010/10 | train MSE 0.01960 | val MSE 85.10287 | PSNR 17.26 dB | SSIM 0.263
# == Zapisano porównanie obrazów do: ./outputs/compare_large.png (legenda: ./outputs/compare_large.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_large_mpl.png
# [shapes][cnn] ep 001/10 | train MSE 0.21900 | val MSE 142.73942 | PSNR 9.08 dB | SSIM 0.018
# [shapes][cnn] ep 002/10 | train MSE 0.13204 | val MSE 118.82875 | PSNR 10.45 dB | SSIM 0.140
# [shapes][cnn] ep 003/10 | train MSE 0.11231 | val MSE 115.44803 | PSNR 10.27 dB | SSIM 0.103
# [shapes][cnn] ep 004/10 | train MSE 0.11102 | val MSE 114.40782 | PSNR 10.15 dB | SSIM 0.067
# [shapes][cnn] ep 005/10 | train MSE 0.11004 | val MSE 113.23751 | PSNR 10.29 dB | SSIM 0.068
# [shapes][cnn] ep 006/10 | train MSE 0.10885 | val MSE 111.71717 | PSNR 10.36 dB | SSIM 0.065
# [shapes][cnn] ep 007/10 | train MSE 0.10660 | val MSE 108.74657 | PSNR 10.88 dB | SSIM 0.082
# [shapes][cnn] ep 008/10 | train MSE 0.10282 | val MSE 105.12703 | PSNR 11.15 dB | SSIM 0.081
# [shapes][cnn] ep 009/10 | train MSE 0.10020 | val MSE 103.00608 | PSNR 11.30 dB | SSIM 0.116
# [shapes][cnn] ep 010/10 | train MSE 0.09785 | val MSE 100.61760 | PSNR 11.41 dB | SSIM 0.089
# [shapes][kan_linear] ep 001/10 | train MSE 0.17536 | val MSE 120.96687 | PSNR 9.64 dB | SSIM 0.033
# [shapes][kan_linear] ep 002/10 | train MSE 0.10382 | val MSE 93.81381 | PSNR 10.96 dB | SSIM 0.061
# [shapes][kan_linear] ep 003/10 | train MSE 0.08092 | val MSE 72.71382 | PSNR 12.10 dB | SSIM 0.092
# [shapes][kan_linear] ep 004/10 | train MSE 0.06305 | val MSE 58.00913 | PSNR 13.00 dB | SSIM 0.118
# [shapes][kan_linear] ep 005/10 | train MSE 0.05151 | val MSE 48.70949 | PSNR 13.69 dB | SSIM 0.142
# [shapes][kan_linear] ep 006/10 | train MSE 0.04438 | val MSE 42.84719 | PSNR 14.19 dB | SSIM 0.167
# [shapes][kan_linear] ep 007/10 | train MSE 0.03979 | val MSE 39.27868 | PSNR 14.50 dB | SSIM 0.189
# [shapes][kan_linear] ep 008/10 | train MSE 0.03681 | val MSE 36.53581 | PSNR 14.77 dB | SSIM 0.213
# [shapes][kan_linear] ep 009/10 | train MSE 0.03442 | val MSE 34.49678 | PSNR 14.99 dB | SSIM 0.236
# [shapes][kan_linear] ep 010/10 | train MSE 0.03253 | val MSE 32.46887 | PSNR 15.23 dB | SSIM 0.257
# [shapes][kan_bezier] ep 001/10 | train MSE 0.16782 | val MSE 121.83331 | PSNR 9.71 dB | SSIM 0.030
# [shapes][kan_bezier] ep 002/10 | train MSE 0.11175 | val MSE 111.97250 | PSNR 10.28 dB | SSIM 0.042
# [shapes][kan_bezier] ep 003/10 | train MSE 0.10695 | val MSE 109.14847 | PSNR 10.36 dB | SSIM 0.047
# [shapes][kan_bezier] ep 004/10 | train MSE 0.10357 | val MSE 104.19529 | PSNR 10.53 dB | SSIM 0.053
# [shapes][kan_bezier] ep 005/10 | train MSE 0.09722 | val MSE 95.87286 | PSNR 10.82 dB | SSIM 0.064
# [shapes][kan_bezier] ep 006/10 | train MSE 0.08757 | val MSE 84.04361 | PSNR 11.43 dB | SSIM 0.077
# [shapes][kan_bezier] ep 007/10 | train MSE 0.07622 | val MSE 73.31350 | PSNR 12.02 dB | SSIM 0.094
# [shapes][kan_bezier] ep 008/10 | train MSE 0.06669 | val MSE 64.67575 | PSNR 12.58 dB | SSIM 0.110
# [shapes][kan_bezier] ep 009/10 | train MSE 0.05939 | val MSE 58.29775 | PSNR 13.05 dB | SSIM 0.124
# [shapes][kan_bezier] ep 010/10 | train MSE 0.05417 | val MSE 54.03686 | PSNR 13.38 dB | SSIM 0.136
# [shapes][kan_catmull] ep 001/10 | train MSE 0.17011 | val MSE 120.15163 | PSNR 9.74 dB | SSIM 0.033
# [shapes][kan_catmull] ep 002/10 | train MSE 0.10857 | val MSE 106.12645 | PSNR 10.44 dB | SSIM 0.048
# [shapes][kan_catmull] ep 003/10 | train MSE 0.09677 | val MSE 92.24593 | PSNR 11.11 dB | SSIM 0.064
# [shapes][kan_catmull] ep 004/10 | train MSE 0.08177 | val MSE 76.00704 | PSNR 11.96 dB | SSIM 0.087
# [shapes][kan_catmull] ep 005/10 | train MSE 0.06724 | val MSE 63.15201 | PSNR 12.73 dB | SSIM 0.110
# [shapes][kan_catmull] ep 006/10 | train MSE 0.05655 | val MSE 54.20476 | PSNR 13.32 dB | SSIM 0.129
# [shapes][kan_catmull] ep 007/10 | train MSE 0.04945 | val MSE 48.37169 | PSNR 13.76 dB | SSIM 0.146
# [shapes][kan_catmull] ep 008/10 | train MSE 0.04477 | val MSE 44.07068 | PSNR 14.10 dB | SSIM 0.161
# [shapes][kan_catmull] ep 009/10 | train MSE 0.04125 | val MSE 41.16826 | PSNR 14.36 dB | SSIM 0.179
# [shapes][kan_catmull] ep 010/10 | train MSE 0.03867 | val MSE 38.61122 | PSNR 14.59 dB | SSIM 0.193
# [shapes][kan_bspline] ep 001/10 | train MSE 0.17137 | val MSE 123.50305 | PSNR 9.62 dB | SSIM 0.029
# [shapes][kan_bspline] ep 002/10 | train MSE 0.11254 | val MSE 112.05195 | PSNR 10.25 dB | SSIM 0.042
# [shapes][kan_bspline] ep 003/10 | train MSE 0.10670 | val MSE 108.71978 | PSNR 10.36 dB | SSIM 0.048
# [shapes][kan_bspline] ep 004/10 | train MSE 0.10264 | val MSE 102.98983 | PSNR 10.62 dB | SSIM 0.053
# [shapes][kan_bspline] ep 005/10 | train MSE 0.09581 | val MSE 93.79596 | PSNR 10.91 dB | SSIM 0.066
# [shapes][kan_bspline] ep 006/10 | train MSE 0.08581 | val MSE 82.09430 | PSNR 11.57 dB | SSIM 0.079
# [shapes][kan_bspline] ep 007/10 | train MSE 0.07482 | val MSE 72.17829 | PSNR 12.06 dB | SSIM 0.096
# [shapes][kan_bspline] ep 008/10 | train MSE 0.06543 | val MSE 63.52204 | PSNR 12.65 dB | SSIM 0.111
# [shapes][kan_bspline] ep 009/10 | train MSE 0.05837 | val MSE 57.41440 | PSNR 13.11 dB | SSIM 0.123
# [shapes][kan_bspline] ep 010/10 | train MSE 0.05308 | val MSE 52.53155 | PSNR 13.46 dB | SSIM 0.138
# [shapes][fastkan] ep 001/10 | train MSE 0.16850 | val MSE 95.89456 | PSNR 11.21 dB | SSIM 0.061
# [shapes][fastkan] ep 002/10 | train MSE 0.07990 | val MSE 67.62199 | PSNR 12.71 dB | SSIM 0.145
# [shapes][fastkan] ep 003/10 | train MSE 0.05737 | val MSE 50.57912 | PSNR 13.74 dB | SSIM 0.230
# [shapes][fastkan] ep 004/10 | train MSE 0.04460 | val MSE 41.50606 | PSNR 14.47 dB | SSIM 0.334
# [shapes][fastkan] ep 005/10 | train MSE 0.03745 | val MSE 35.63610 | PSNR 14.99 dB | SSIM 0.419
# [shapes][fastkan] ep 006/10 | train MSE 0.03284 | val MSE 31.71362 | PSNR 15.45 dB | SSIM 0.467
# [shapes][fastkan] ep 007/10 | train MSE 0.02956 | val MSE 28.72772 | PSNR 15.81 dB | SSIM 0.514
# [shapes][fastkan] ep 008/10 | train MSE 0.02714 | val MSE 26.56874 | PSNR 16.10 dB | SSIM 0.541
# [shapes][fastkan] ep 009/10 | train MSE 0.02527 | val MSE 24.85631 | PSNR 16.38 dB | SSIM 0.567
# [shapes][fastkan] ep 010/10 | train MSE 0.02371 | val MSE 23.30891 | PSNR 16.64 dB | SSIM 0.581
# == Zapisano porównanie obrazów do: ./outputs/compare_shapes.png (legenda: ./outputs/compare_shapes.txt)
# == Zapisano porównanie Matplotlib do: ./outputs/compare_shapes_mpl.png
#
# == Zapisano wyniki do: ./outputs/results_final_128.csv
#     dataset   H   W        model  latent_dim   params  epochs     val_mse  \
# 0     mnist  28  28          cnn         128   524353      10    4.691430
# 1     mnist  28  28   kan_linear         128  1204224      10    2.423923
# 2     mnist  28  28   kan_bezier         128  1204224      10    6.515700
# 3     mnist  28  28  kan_catmull         128  1204224      10    3.165733
# 4     mnist  28  28  kan_bspline         128  1204224      10    5.913546
# 5     mnist  28  28      fastkan         128  1809088      10    1.690703
# 6   cifar16  16  16          cnn         128   296769      10    3.012621
# 7   cifar16  16  16   kan_linear         128   393216      10    0.531501
# 8   cifar16  16  16   kan_bezier         128   393216      10    1.643971
# 9   cifar16  16  16  kan_catmull         128   393216      10    0.947926
# 10  cifar16  16  16  kan_bspline         128   393216      10    1.604829
# 11  cifar16  16  16      fastkan         128   590992      10    0.572981
# 12    large  64  64          cnn         128  1516929      10   99.299422
# 13    large  64  64   kan_linear         128  6291456      10   95.370662
# 14    large  64  64   kan_bezier         128  6291456      10  102.921118
# 15    large  64  64  kan_catmull         128  6291456      10  106.195565
# 16    large  64  64  kan_bspline         128  6291456      10  105.581484
# 17    large  64  64      fastkan         128  9449872      10   85.102869
# 18   shapes  32  32          cnn         128   648193      10  100.617597
# 19   shapes  32  32   kan_linear         128  1572864      10   32.468872
# 20   shapes  32  32   kan_bezier         128  1572864      10   54.036865
# 21   shapes  32  32  kan_catmull         128  1572864      10   38.611218
# 22   shapes  32  32  kan_bspline         128  1572864      10   52.531550
# 23   shapes  32  32      fastkan         128  2362768      10   23.308906
#
#      val_psnr  val_ssim  infer_ms_per_img
# 0   23.098408  0.935128          0.451215
# 1   25.837185  0.905299          0.581744
# 2   21.482409  0.841811          1.948878
# 3   24.643490  0.888275          3.043123
# 4   21.924543  0.850774          2.509987
# 5   27.356321  0.944522          0.020972
# 6   20.034704  0.603260          0.127279
# 7   27.497526  0.947383          0.241183
# 8   22.611917  0.818885          0.663862
# 9   24.951171  0.907515          1.014624
# 10  22.709354  0.822658          0.963505
# 11  27.032873  0.940469          0.020298
# 12  16.727959  0.274219          2.811129
# 13  16.850521  0.258294          4.122212
# 14  16.555921  0.239807         11.203567
# 15  16.403376  0.236902         13.660563
# 16  16.448388  0.233252         13.325730
# 17  17.256235  0.263480          0.089120
# 18  11.413553  0.089086          0.654452
# 19  15.229340  0.256529          0.835793
# 20  13.378930  0.135538          3.027836
# 21  14.588259  0.192903          3.280210
# 22  13.460772  0.137545          3.295049
# 23  16.644495  0.580994          0.044322
# ['cnn', 'kan_linear', 'kan_bezier', 'kan_catmull', 'kan_bspline', 'fastkan']
# [mnist][cnn] ep 001/10 | train MSE 0.05283 | val MSE 19.87436 | PSNR 16.52 dB | SSIM 0.737
# [mnist][cnn] ep 002/10 | train MSE 0.01921 | val MSE 13.00956 | PSNR 18.55 dB | SSIM 0.828
# [mnist][cnn] ep 003/10 | train MSE 0.01398 | val MSE 9.87593 | PSNR 19.84 dB | SSIM 0.867
# [mnist][cnn] ep 004/10 | train MSE 0.01158 | val MSE 8.46376 | PSNR 20.53 dB | SSIM 0.886
# [mnist][cnn] ep 005/10 | train MSE 0.01007 | val MSE 7.67260 | PSNR 20.92 dB | SSIM 0.895
# [mnist][cnn] ep 006/10 | train MSE 0.00907 | val MSE 6.73655 | PSNR 21.56 dB | SSIM 0.906
# [mnist][cnn] ep 007/10 | train MSE 0.00837 | val MSE 6.69166 | PSNR 21.47 dB | SSIM 0.903
# [mnist][cnn] ep 008/10 | train MSE 0.00776 | val MSE 6.23169 | PSNR 21.78 dB | SSIM 0.915
# [mnist][cnn] ep 009/10 | train MSE 0.00728 | val MSE 5.74869 | PSNR 22.18 dB | SSIM 0.920
# [mnist][cnn] ep 010/10 | train MSE 0.00687 | val MSE 5.49442 | PSNR 22.27 dB | SSIM 0.923
# [mnist][kan_linear] ep 001/10 | train MSE 0.03718 | val MSE 15.60743 | PSNR 17.48 dB | SSIM 0.628
# [mnist][kan_linear] ep 002/10 | train MSE 0.01633 | val MSE 10.74555 | PSNR 19.21 dB | SSIM 0.728
# [mnist][kan_linear] ep 003/10 | train MSE 0.01211 | val MSE 8.47697 | PSNR 20.30 dB | SSIM 0.773
# [mnist][kan_linear] ep 004/10 | train MSE 0.00986 | val MSE 7.19741 | PSNR 21.05 dB | SSIM 0.800
# [mnist][kan_linear] ep 005/10 | train MSE 0.00845 | val MSE 6.39042 | PSNR 21.58 dB | SSIM 0.824
# [mnist][kan_linear] ep 006/10 | train MSE 0.00747 | val MSE 5.64449 | PSNR 22.15 dB | SSIM 0.833
# [mnist][kan_linear] ep 007/10 | train MSE 0.00673 | val MSE 5.15517 | PSNR 22.56 dB | SSIM 0.846
# [mnist][kan_linear] ep 008/10 | train MSE 0.00616 | val MSE 4.75463 | PSNR 22.94 dB | SSIM 0.859
# [mnist][kan_linear] ep 009/10 | train MSE 0.00572 | val MSE 4.45487 | PSNR 23.23 dB | SSIM 0.863
# [mnist][kan_linear] ep 010/10 | train MSE 0.00534 | val MSE 4.21124 | PSNR 23.49 dB | SSIM 0.876
# [mnist][kan_bezier] ep 001/10 | train MSE 0.05660 | val MSE 32.18279 | PSNR 14.11 dB | SSIM 0.383
# [mnist][kan_bezier] ep 002/10 | train MSE 0.03621 | val MSE 25.29492 | PSNR 15.25 dB | SSIM 0.487
# [mnist][kan_bezier] ep 003/10 | train MSE 0.02994 | val MSE 21.68850 | PSNR 15.98 dB | SSIM 0.556
# [mnist][kan_bezier] ep 004/10 | train MSE 0.02604 | val MSE 19.18853 | PSNR 16.57 dB | SSIM 0.600
# [mnist][kan_bezier] ep 005/10 | train MSE 0.02328 | val MSE 17.34525 | PSNR 17.05 dB | SSIM 0.638
# [mnist][kan_bezier] ep 006/10 | train MSE 0.02125 | val MSE 16.18070 | PSNR 17.38 dB | SSIM 0.669
# [mnist][kan_bezier] ep 007/10 | train MSE 0.01972 | val MSE 15.01607 | PSNR 17.73 dB | SSIM 0.677
# [mnist][kan_bezier] ep 008/10 | train MSE 0.01850 | val MSE 14.13548 | PSNR 18.00 dB | SSIM 0.700
# [mnist][kan_bezier] ep 009/10 | train MSE 0.01751 | val MSE 13.47154 | PSNR 18.23 dB | SSIM 0.715
# [mnist][kan_bezier] ep 010/10 | train MSE 0.01670 | val MSE 12.81335 | PSNR 18.48 dB | SSIM 0.730
# [mnist][kan_catmull] ep 001/10 | train MSE 0.04268 | val MSE 19.42507 | PSNR 16.46 dB | SSIM 0.543
# [mnist][kan_catmull] ep 002/10 | train MSE 0.02013 | val MSE 13.26902 | PSNR 18.22 dB | SSIM 0.652
# [mnist][kan_catmull] ep 003/10 | train MSE 0.01497 | val MSE 10.58716 | PSNR 19.27 dB | SSIM 0.711
# [mnist][kan_catmull] ep 004/10 | train MSE 0.01222 | val MSE 8.79702 | PSNR 20.12 dB | SSIM 0.754
# [mnist][kan_catmull] ep 005/10 | train MSE 0.01046 | val MSE 7.69587 | PSNR 20.72 dB | SSIM 0.777
# [mnist][kan_catmull] ep 006/10 | train MSE 0.00921 | val MSE 6.81837 | PSNR 21.28 dB | SSIM 0.802
# [mnist][kan_catmull] ep 007/10 | train MSE 0.00828 | val MSE 6.19649 | PSNR 21.71 dB | SSIM 0.817
# [mnist][kan_catmull] ep 008/10 | train MSE 0.00756 | val MSE 5.77834 | PSNR 22.00 dB | SSIM 0.827
